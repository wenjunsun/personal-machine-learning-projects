# %% [markdown]
# <a href="https://colab.research.google.com/github/wenjunsun/personal-machine-learning-projects/blob/master/cancer-fracture/task1/prepare_data_for_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook we will try to prepare the data necessary for machine learning prediction. The upshot is to use the data 90 days before the stem cell transplant of a patient with myeloma to predict if there will be fracture of bones after the stem cell transplant.

# %%
cd drive/My\ Drive/fracture_with_emissa/Datasets/Raw\ Data
# Out:
# /content/drive/My Drive/fracture_with_emissa/Datasets/Raw Data

# %%
ls
# Out:
# BillingCodes.csv          Medications.csv
# BonyLesions.csv           medicines_90_days_before_STC.csv
# data_agg.csv              MyelomaTherapy.csv
# Demographics.csv          PlasmaCells.csv
# Demographics_encoded.csv  RadiationTherapy.csv
# Diagnoses.csv             Signs.csv
# Fractures.csv             Stage.csv
# Labs2.csv                 Stages_encoded.csv
# Labs_closest_to_SCT.csv   SurvivalDays.csv
# Labs.csv                  Symptoms.csv
# Lesions_encoded.csv

# %%
import pandas as pd

# %% [markdown]
# # 1. prepare data from lab results.

# %% [markdown]
# In this section we will do the following:
#
# First extract the day on which each patient have the stem cell transplant, then we find in the lab results csv file the closest lab results to the SCT (SCT stands for stem cell transplant) date, which will be provided as features to our machine learning models later.

# %% [markdown]
# ## 1.1 extract the date of SCT for each patient

# %%
data = pd.read_csv('MyelomaTherapy.csv')

# %%
data.head()
# Out:
#     ID             MedTx    Combination  ... Line Duration  TreatmentPhase
# 0  MM1        Bortezomib            VRD  ...    1    195.0       Induction
# 1  MM1     Dexamethasone            VRD  ...    1    195.0       Induction
# 2  MM1      Lenalidomide            VRD  ...    1    195.0       Induction
# 3  MM1  Cyclophosphamide  Not specified  ...    2     32.0       Induction
# 4  MM1     Dexamethasone  Not specified  ...    2     32.0       Induction
#
# [5 rows x 10 columns]

# %%
data[data['ID'] == 'MM1']
# Out:
#     ID                 MedTx  ... Duration        TreatmentPhase
# 0  MM1            Bortezomib  ...    195.0             Induction
# 1  MM1         Dexamethasone  ...    195.0             Induction
# 2  MM1          Lenalidomide  ...    195.0             Induction
# 3  MM1      Cyclophosphamide  ...     32.0             Induction
# 4  MM1         Dexamethasone  ...     32.0             Induction
# 5  MM1  Stem cell transplant  ...    114.0  Stem cell transplant
# 6  MM1            Bortezomib  ...      NaN           Maintenance
#
# [7 rows x 10 columns]

# %% [markdown]
# As we can see, patient MM1 has the stem cell transplant on day 343. We want to extract this number for each patient. And store the information in a python dictionary.
#
# For example, the dictionary may look like this after processing: `{'MM1': 343, 'MM2': 200, ...}`

# %%
data[data['ID'] == 'MM3']
# Out:
#      ID          MedTx Combination  ... Line Duration  TreatmentPhase
# 15  MM3  Dexamethasone         VRD  ...    1      NaN       Induction
# 16  MM3   Lenalidomide         VRD  ...    1      NaN       Induction
# 17  MM3     Bortezomib         VRD  ...    1      NaN       Induction
#
# [3 rows x 10 columns]

# %% [markdown]
# As we can see. Patient MM3 didn't do SCT. So our dictionary will simply not store its mapping. In other words, after processing dictionary won't have MM3 as one of its keys. We are only focusing on the STC patients for now.

# %%
data[data['ID'] == 'MM20']
# Out:
#        ID                  MedTx  ... Duration        TreatmentPhase
# 221  MM20             Bortezomib  ...     69.0             Induction
# 222  MM20          Dexamethasone  ...     69.0             Induction
# 223  MM20       Cyclophosphamide  ...     69.0             Induction
# 224  MM20             Bortezomib  ...     29.0             Induction
# 225  MM20             Bortezomib  ...    167.0             Induction
# 226  MM20           Lenalidomide  ...    167.0             Induction
# 227  MM20          Dexamethasone  ...    167.0             Induction
# 228  MM20  Liposomal doxorubicin  ...     89.0             Induction
# 229  MM20            Carfilzomib  ...     89.0             Induction
# 230  MM20          Dexamethasone  ...     89.0             Induction
# 231  MM20       Cyclophosphamide  ...     41.0             Induction
# 232  MM20              Cisplatin  ...     41.0             Induction
# 233  MM20            Thalidomide  ...     41.0             Induction
# 234  MM20             Bortezomib  ...     41.0             Induction
# 235  MM20            Doxorubicin  ...     41.0             Induction
# 236  MM20              Etoposide  ...     41.0             Induction
# 237  MM20          Dexamethasone  ...     41.0             Induction
# 238  MM20             Bortezomib  ...     41.0             Induction
# 239  MM20   Stem cell transplant  ...    128.0  Stem cell transplant
# 240  MM20   Stem cell transplant  ...      NaN  Stem cell transplant
#
# [20 rows x 10 columns]

# %% [markdown]
# As we can see, patient MM20 had 2 stem cell transplant treatment. In this case the dictionary will simply store day of his/her first treatment

# %%
STC_data = data[data['MedTx'] == 'Stem cell transplant']

# %%
STC_data
# Out:
#          ID                 MedTx  ... Duration        TreatmentPhase
# 5       MM1  Stem cell transplant  ...    114.0  Stem cell transplant
# 14      MM2  Stem cell transplant  ...      NaN  Stem cell transplant
# 25      MM4  Stem cell transplant  ...     98.0  Stem cell transplant
# 29      MM5  Stem cell transplant  ...    435.0  Stem cell transplant
# 37      MM6  Stem cell transplant  ...    107.0  Stem cell transplant
# ...     ...                   ...  ...      ...                   ...
# 9893  MM836  Stem cell transplant  ...     58.0  Stem cell transplant
# 9894  MM836  Stem cell transplant  ...    210.0  Stem cell transplant
# 9899  MM837  Stem cell transplant  ...      NaN  Stem cell transplant
# 9905  MM838  Stem cell transplant  ...     92.0  Stem cell transplant
# 9906  MM838  Stem cell transplant  ...    199.0  Stem cell transplant
#
# [872 rows x 10 columns]

# %%
STC_data.iloc[1,5]
# Out:
# 229.0

# %%
# the dictionary that looks like this: {'MM1': 343, 'MM2': 200, ...}
# patient ID -> Days from diagnosis that patient used STC
patientToDayOfSTC = dict()
for i in range(STC_data.shape[0]):
  ID = STC_data.iloc[i, 0] # 0th column is the ID column, i is the row number
  day = STC_data.iloc[i, 5] # 5th column is the DaysFromDxStart column, 
                            # which is the day which patient used STC
  if ID not in patientToDayOfSTC:
    patientToDayOfSTC[ID] = day
  else:
    continue # we only keep the first day of STC treatment, ignore the later ones.

# %%
len(patientToDayOfSTC)
# Out:
# 702

# %% [markdown]
# So we have 702 patient who did the STC.

# %% [markdown]
# ## 1.2 extrat the closest lab results to STC date from Labs.csv

# %%
data = pd.read_csv('Labs.csv')

# %%
data.head()
# Out:
#     ID ObservationId  ... LowerLimit UpperLimit
# 0  MM1             P  ...        2.5        4.5
# 1  MM1           PLT  ...        150        400
# 2  MM1           ALK  ...         36        161
# 3  MM1         RDWCV  ...       11.6       14.4
# 4  MM1         RDWCV  ...       11.6       14.4
#
# [5 rows x 10 columns]

# %%
data[(data['ID'] == 'MM1') & (data['ObservationName'] == 'Calcium')].sort_values(by = ['DaysFromDx'])
# Out:
#       ID ObservationId ObservationName  ... AbnormalFlags  LowerLimit UpperLimit
# 592  MM1            CA         Calcium  ...             L         8.9       10.2
# 130  MM1            CA         Calcium  ...             N         8.9       10.2
# 271  MM1            CA         Calcium  ...             N         8.9       10.2
# 172  MM1            CA         Calcium  ...             N         8.9       10.2
# 186  MM1            CA         Calcium  ...             N         8.9       10.2
# 459  MM1            CA         Calcium  ...             N         8.9       10.2
# 353  MM1            CA         Calcium  ...             N         8.9       10.2
# 6    MM1            CA         Calcium  ...             N         8.9       10.2
# 320  MM1            CA         Calcium  ...             N         8.9       10.2
# 74   MM1            CA         Calcium  ...             N         8.9       10.2
# 298  MM1            CA         Calcium  ...             L         8.9       10.2
# 234  MM1            CA         Calcium  ...             L         8.9       10.2
# 340  MM1            CA         Calcium  ...             L         8.9       10.2
# 102  MM1            CA         Calcium  ...             L         8.9       10.2
# 117  MM1            CA         Calcium  ...             N         8.9       10.2
# 636  MM1            CA         Calcium  ...             N         8.9       10.2
# 293  MM1            CA         Calcium  ...             N         8.9       10.2
# 434  MM1            CA         Calcium  ...             N         8.9       10.2
# 203  MM1            CA         Calcium  ...             N         8.9       10.2
# 23   MM1            CA         Calcium  ...             N         8.9       10.2
# 231  MM1            CA         Calcium  ...             N         8.9       10.2
# 256  MM1            CA         Calcium  ...             L         8.9       10.2
# 309  MM1            CA         Calcium  ...             L         8.9       10.2
# 518  MM1            CA         Calcium  ...             L         8.9       10.2
# 693  MM1            CA         Calcium  ...             L         8.9       10.2
# 507  MM1            CA         Calcium  ...             L         8.9       10.2
# 233  MM1            CA         Calcium  ...             L         8.9       10.2
# 468  MM1            CA         Calcium  ...             L         8.9       10.2
# 632  MM1            CA         Calcium  ...             L         8.9       10.2
# 34   MM1            CA         Calcium  ...             L         8.9       10.2
# 141  MM1            CA         Calcium  ...             L         8.9       10.2
# 341  MM1            CA         Calcium  ...             L         8.9       10.2
# 487  MM1            CA         Calcium  ...             L         8.9       10.2
# 306  MM1            CA         Calcium  ...             L         8.9       10.2
# 302  MM1            CA         Calcium  ...             L         8.9       10.2
# 448  MM1            CA         Calcium  ...             L         8.9       10.2
# 394  MM1            CA         Calcium  ...             N         8.9       10.2
# 559  MM1            CA         Calcium  ...             N         8.9       10.2
# 275  MM1            CA         Calcium  ...             N         8.9       10.2
# 410  MM1            CA         Calcium  ...             N         8.9       10.2
# 87   MM1            CA         Calcium  ...             N         8.9       10.2
#
# [41 rows x 10 columns]

# %%
patientToDayOfSTC['MM1']
# Out:
# 343.0

# %% [markdown]
# For example, as shown above, the row we are going to preserve for patient MM1 about his/her lab results about Calcium, we will choose the lab done the closest to 343 but prior to 343, which in this case is row with index 23 (having the date value of 343). That is the row that will go to our result dataframe.

# %%
data['ObservationName'].unique()
# Out:
# array(['Phosphate', 'Platelet\xa0Count', 'Alkaline\xa0Phosphatase',
#        'Red Blood Cell Distribution Width', 'Calcium',
#        'White Blood Cell Count', 'Hematocrit', 'Total Protein',
#        'Mean Corpuscular Volume', 'Albumin', 'Neutrophils', 'Lymphocytes',
#        'Creatinine', 'Lactate\xa0Dehydrogenase', 'Hemoglobin',
#        'Aspartate Aminotransferase', 'Alanine\xa0Aminotransferase\xa0',
#        'Beta-2\xa0Microglobulin', 'Total Bilirubin', 'Monoclonal protein',
#        'Cytomegalovirus PCR', 'Immunoglobulin\xa0G',
#        'C.\xa0difficile PCR', 'Total Cholesterol',
#        'Bence\xa0Jones\xa0Protein', 'Immunoglobulin\xa0A',
#        'Varicella Zoster\xa0Antibody', 'Immunoglobulin\xa0M',
#        'C-Reactive Protein', 'Free light chain ratio', 'Testosterone',
#        'Prostate\xa0Specific\xa0Antigen', 'Vitamin\xa0D3',
#        'Triglycerides', 'Blasts', 'Thyroid\xa0Stimulating\xa0Hormone',
#        'Iron', 'Sedimentation\xa0Rate', 'Troponin I',
#        'Parathyroid hormone', 'Ferritin', 'Folate', 'Vitamin\xa0B12',
#        'High-Density Lipoprotein', 'Norovirus\xa0type\xa02',
#        'Norovirus\xa0type\xa01', 'Norovirus\xa0type\xa04',
#        'Adenovirus\xa0PCR', 'Influenza\xa0A\xa0PCR',
#        'Parainfluenza\xa03\xa0PCR', 'Rhinovirus\xa0PCR',
#        'Parainfluenza\xa01\xa0PCR', 'Bocavirus\xa0PCR',
#        'Influenza\xa0B\xa0PCR', 'Metapneumovirus\xa0PCR',
#        'Coronavirus\xa0PCR', 'Parainfluenza\xa02\xa0PCR',
#        'Parainfluenza\xa04\xa0PCR', 'Respiratory Syncytial Virus PCR',
#        'Hepatitis\xa0C Antibody', 'Hepatitis\xa0B\xa0Surface\xa0Antigen',
#        'Hepatitis\xa0B\xa0Surface\xa0Antibody', 'Hemoglobin\xa0A1C',
#        'Hepatitis\xa0B\xa0Core Antibody',
#        'Brain\xa0Natriuretic\xa0Peptide',
#        'Chimerism\xa0Whole\xa0Bone Marrow Cells', 'Cortisol',
#        'Serum Viscosity',
#        'Chimerism\xa0Peripheral Blood\xa0CD3+\xa0Cells',
#        'Low-Density Lipoprotein', 'Estradiol',
#        'Chimerism\xa0Peripheral Blood\xa0CD33+\xa0Cells',
#        'Quantiferon\xa0TB', 'Urine BK\xa0Virus',
#        'S.\xa0pneumoniae\xa0antibody'], dtype=object)

# %%
# the chemicals we think are important for prediction.
# don't think we have estrogen, but estradiol?
important_chemicals = ['Calcium', 'Phosphate', 'Parathyroid hormone', \
                       'Alkaline\xa0Phosphatase', 'Vitamin\xa0D3', \
                       'Estradiol', 'Testosterone', 'Thyroid\xa0Stimulating\xa0Hormone',\
                       'Creatinine', 'C-Reactive Protein', 'Sedimentation\xa0Rate']

# %%
result_df = pd.DataFrame(columns = data.columns)

# %%
result_df
# Out:
# Empty DataFrame
# Columns: [ID, ObservationId, ObservationName, Panel, DaysFromDx, ObservationValueNumeric, Units, AbnormalFlags, LowerLimit, UpperLimit]
# Index: []

# %%
progress = 0
for ID, patient_STC_day in patientToDayOfSTC.items():
  
  for chemical in important_chemicals:
    # get this patient's lab results history of this chemical

    patient_data = data[(data['ID'] == ID) & (data['ObservationName'] == chemical)]
    
    if patient_data.shape[0] != 0:
      row_to_be_added = None # the variable that stores the row that will be added to our result dataframe.
      
      # get the row with lowest day after STC date
      # set this to row_to_be_added first so it can be overwritten by
      # the highest day before STC date later. 
      patient_labs_after_STC = patient_data[patient_data['DaysFromDx'] > patient_STC_day]
      if patient_labs_after_STC.shape[0] != 0:
        row_to_be_added = patient_labs_after_STC[patient_labs_after_STC.DaysFromDx == patient_labs_after_STC.DaysFromDx.min()]
      
      # set the row to be the one with highest day (closest) to STC date
      # if there are any such rows.
      patient_labs_before_STC = patient_data[patient_data['DaysFromDx'] <= patient_STC_day]
      if patient_labs_before_STC.shape[0] != 0:
        row_to_be_added = patient_labs_before_STC[patient_labs_before_STC.DaysFromDx == patient_labs_before_STC.DaysFromDx.max()]
      
      # if the row is not None, that means we have found a row with the "closest" date to STC date
      # add this row to result dataframe
      if row_to_be_added is not None:
        result_df = result_df.append(row_to_be_added, ignore_index=True)
      # else:
        # else we know we don't have any data on 

  progress += 1
  if (progress % 10 == 0):
    print(f'Progress bar: {progress / len(patientToDayOfSTC)}')
# Out:
# Progress bar: 0.014245014245014245
# Progress bar: 0.02849002849002849
# Progress bar: 0.042735042735042736
# Progress bar: 0.05698005698005698
# Progress bar: 0.07122507122507123
# Progress bar: 0.08547008547008547
# Progress bar: 0.09971509971509972
# Progress bar: 0.11396011396011396
# Progress bar: 0.1282051282051282
# Progress bar: 0.14245014245014245
# Progress bar: 0.15669515669515668
# Progress bar: 0.17094017094017094
# Progress bar: 0.18518518518518517
# Progress bar: 0.19943019943019943
# Progress bar: 0.21367521367521367
# Progress bar: 0.22792022792022792
# Progress bar: 0.24216524216524216
# Progress bar: 0.2564102564102564
# Progress bar: 0.2706552706552707
# Progress bar: 0.2849002849002849
# Progress bar: 0.29914529914529914
# Progress bar: 0.31339031339031337
# Progress bar: 0.32763532763532766
# Progress bar: 0.3418803418803419
# Progress bar: 0.3561253561253561
# Progress bar: 0.37037037037037035
# Progress bar: 0.38461538461538464
# Progress bar: 0.39886039886039887
# Progress bar: 0.4131054131054131
# Progress bar: 0.42735042735042733
# Progress bar: 0.4415954415954416
# Progress bar: 0.45584045584045585
# Progress bar: 0.4700854700854701
# Progress bar: 0.4843304843304843
# Progress bar: 0.4985754985754986
# Progress bar: 0.5128205128205128
# Progress bar: 0.5270655270655271
# Progress bar: 0.5413105413105413
# Progress bar: 0.5555555555555556
# Progress bar: 0.5698005698005698
# Progress bar: 0.584045584045584
# Progress bar: 0.5982905982905983
# Progress bar: 0.6125356125356125
# Progress bar: 0.6267806267806267
# Progress bar: 0.6410256410256411
# Progress bar: 0.6552706552706553
# Progress bar: 0.6695156695156695
# Progress bar: 0.6837606837606838
# Progress bar: 0.698005698005698
# Progress bar: 0.7122507122507122
# Progress bar: 0.7264957264957265
# Progress bar: 0.7407407407407407
# Progress bar: 0.7549857549857549
# Progress bar: 0.7692307692307693
# Progress bar: 0.7834757834757835
# Progress bar: 0.7977207977207977
# Progress bar: 0.811965811965812
# Progress bar: 0.8262108262108262
# Progress bar: 0.8404558404558404
# Progress bar: 0.8547008547008547
# Progress bar: 0.8689458689458689
# Progress bar: 0.8831908831908832
# Progress bar: 0.8974358974358975
# Progress bar: 0.9116809116809117
# Progress bar: 0.9259259259259259
# Progress bar: 0.9401709401709402
# Progress bar: 0.9544159544159544
# Progress bar: 0.9686609686609686
# Progress bar: 0.9829059829059829
# Progress bar: 0.9971509971509972

# %%
result_df
# Out:
#          ID ObservationId  ... LowerLimit UpperLimit
# 0       MM1            CA  ...        8.9       10.2
# 1       MM1             P  ...        2.5        4.5
# 2       MM1           ALK  ...         36        161
# 3       MM1         VITD3  ...         20        100
# 4       MM1          TEST  ...        1.6        5.9
# ...     ...           ...  ...        ...        ...
# 5254  MM838         VITD3  ...         20        100
# 5255  MM838          TEST  ...        1.6        5.9
# 5256  MM838           TSH  ...        0.4          5
# 5257  MM838           CRE  ...        0.3        1.2
# 5258  MM838         HSCRP  ...          0         10
#
# [5259 rows x 10 columns]

# %% [markdown]
# All right, let's now check if our result is right, by looking at the data we extracted for patient MM2!

# %%
# our extracted data
result_df[result_df['ID'] == 'MM2']
# Out:
#      ID ObservationId       ObservationName  ... AbnormalFlags LowerLimit UpperLimit
# 7   MM2            CA               Calcium  ...             N        8.9       10.2
# 8   MM2             P             Phosphate  ...             N        2.5        4.5
# 9   MM2           ALK  Alkaline Phosphatase  ...             N         37        159
# 10  MM2         VITD3            Vitamin D3  ...             L         20        100
# 11  MM2          TEST          Testosterone  ...             N        1.6        5.9
# 12  MM2           CRE            Creatinine  ...             N       0.51       1.18
# 13  MM2         HSCRP    C-Reactive Protein  ...             N          0         10
#
# [7 rows x 10 columns]

# %%
patientToDayOfSTC['MM2']
# Out:
# 229.0

# %%
# original data
data[(data['ID'] == 'MM2') & (data['ObservationName'] == 'Calcium')].sort_values(by = ['DaysFromDx'])
# Out:
#        ID ObservationId ObservationName  ... AbnormalFlags  LowerLimit UpperLimit
# 1175  MM2            CA         Calcium  ...             N         8.9       10.2
# 1231  MM2            CA         Calcium  ...             L         8.9       10.2
# 740   MM2            CA         Calcium  ...             N         8.9       10.2
# 1128  MM2            CA         Calcium  ...             N         8.9       10.2
# 1191  MM2            CA         Calcium  ...             N         8.9       10.2
# 805   MM2            CA         Calcium  ...             N         8.9       10.2
# 1230  MM2            CA         Calcium  ...             L         8.9       10.2
# 907   MM2            CA         Calcium  ...             N         8.9       10.2
# 802   MM2            CA         Calcium  ...             L         8.9       10.2
# 939   MM2            CA         Calcium  ...             L         8.9       10.2
# 1174  MM2            CA         Calcium  ...             L         8.9       10.2
# 944   MM2            CA         Calcium  ...             L         8.9       10.2
# 708   MM2            CA         Calcium  ...             L         8.9       10.2
# 816   MM2            CA         Calcium  ...             N         8.9       10.2
# 796   MM2            CA         Calcium  ...             L         8.9       10.2
# 973   MM2            CA         Calcium  ...             N         8.9       10.2
# 716   MM2            CA         Calcium  ...             N         8.9       10.2
# 994   MM2            CA         Calcium  ...             N         8.9       10.2
# 1017  MM2            CA         Calcium  ...             N         8.9       10.2
# 1394  MM2            CA         Calcium  ...             N         8.9       10.2
# 1329  MM2            CA         Calcium  ...             L         8.9       10.2
# 1164  MM2            CA         Calcium  ...             N         8.9       10.2
# 1224  MM2            CA         Calcium  ...             L         8.9       10.2
# 949   MM2            CA         Calcium  ...             L         8.9       10.2
# 941   MM2            CA         Calcium  ...             L         8.9       10.2
# 745   MM2            CA         Calcium  ...             L         8.9       10.2
# 849   MM2            CA         Calcium  ...             L         8.9       10.2
# 794   MM2            CA         Calcium  ...             L         8.9       10.2
# 1326  MM2            CA         Calcium  ...             L         8.9       10.2
# 906   MM2            CA         Calcium  ...             L         8.9       10.2
# 1157  MM2            CA         Calcium  ...             L         8.9       10.2
# 1256  MM2            CA         Calcium  ...             L         8.9       10.2
# 1333  MM2            CA         Calcium  ...             L         8.9       10.2
# 1336  MM2            CA         Calcium  ...             N         8.9       10.2
# 868   MM2            CA         Calcium  ...             L         8.9       10.2
# 1259  MM2            CA         Calcium  ...             N         8.9       10.2
# 738   MM2            CA         Calcium  ...             N         8.9       10.2
# 870   MM2            CA         Calcium  ...             N         8.9       10.2
# 916   MM2            CA         Calcium  ...             N         8.9       10.2
# 833   MM2            CA         Calcium  ...             N         8.9       10.2
# 953   MM2            CA         Calcium  ...             N         8.9       10.2
# 945   MM2            CA         Calcium  ...             N         8.9       10.2
# 887   MM2            CA         Calcium  ...             N         8.9       10.2
# 1217  MM2            CA         Calcium  ...             N         8.9       10.2
# 867   MM2            CA         Calcium  ...             N         8.9       10.2
#
# [45 rows x 10 columns]

# %%
data[(data['ID'] == 'MM2') & (data['ObservationName'] == 'Phosphate')].sort_values(by = ['DaysFromDx'])
# Out:
#        ID ObservationId ObservationName  ... AbnormalFlags  LowerLimit UpperLimit
# 977   MM2             P       Phosphate  ...             N         2.5        4.5
# 1135  MM2             P       Phosphate  ...             N         2.5        4.5
# 1257  MM2             P       Phosphate  ...             N         2.5        4.5
# 1027  MM2             P       Phosphate  ...             N         2.5        4.5
# 961   MM2             P       Phosphate  ...             N         2.5        4.5
# 827   MM2             P       Phosphate  ...             N         2.5        4.5
# 1286  MM2             P       Phosphate  ...             N         2.5        4.5
# 1050  MM2             P       Phosphate  ...             N         2.5        4.5
# 1115  MM2             P       Phosphate  ...             N         2.5        4.5
# 1003  MM2             P       Phosphate  ...             L         2.5        4.5
# 1220  MM2             P       Phosphate  ...             N         2.5        4.5
# 1282  MM2             P       Phosphate  ...             N         2.5        4.5
# 1002  MM2             P       Phosphate  ...             N         2.5        4.5
# 1278  MM2             P       Phosphate  ...             N         2.5        4.5
# 1373  MM2             P       Phosphate  ...             N         2.5        4.5
# 1240  MM2             P       Phosphate  ...             N         2.5        4.5
# 1344  MM2             P       Phosphate  ...             N         2.5        4.5
# 968   MM2             P       Phosphate  ...             L         2.5        4.5
# 1132  MM2             P       Phosphate  ...             N         2.5        4.5
# 1378  MM2             P       Phosphate  ...             N         2.5        4.5
# 1076  MM2             P       Phosphate  ...             N         2.5        4.5
# 895   MM2             P       Phosphate  ...             N         2.5        4.5
# 990   MM2             P       Phosphate  ...             N         2.5        4.5
# 883   MM2             P       Phosphate  ...             N         2.5        4.5
# 832   MM2             P       Phosphate  ...             N         2.5        4.5
# 923   MM2             P       Phosphate  ...             N         2.5        4.5
#
# [26 rows x 10 columns]

# %%
data[(data['ID'] == 'MM2') & (data['ObservationName'] == 'Parathyroid hormone')].sort_values(by = ['DaysFromDx'])
# Out:
# Empty DataFrame
# Columns: [ID, ObservationId, ObservationName, Panel, DaysFromDx, ObservationValueNumeric, Units, AbnormalFlags, LowerLimit, UpperLimit]
# Index: []

# %% [markdown]
# Which we can see from the above dataframes that we indeed get the right rows in our `result_df`. There is no data about Parathyroid hormone for MM2 patient, so there isn't a row for that in the result_df.
#
# Let's now save this as a csv file.

# %%
result_df.to_csv('Labs_closest_to_SCT.csv', index = False)

# %% [markdown]
# # 2. encode demographics data.

# %% [markdown]
# In this section we will encode the demographics data in the following fashion:
#
# Race: White:1, Black: 2, Asian: 3, Other or if there is no information for the race of the patient: 4
#
# Sex       M=1, F=0
#
# Age  :     <=69 : 1,       >=70: 0

# %%
data = pd.read_csv('Demographics.csv')

# %%
data
# Out:
#         ID  AgeAtDx PatientSex RacialGroup
# 0      MM1       67       Male       White
# 1      MM2       61       Male       Black
# 2      MM3       59       Male       White
# 3      MM4       68     Female       White
# 4      MM5       63       Male       White
# ..     ...      ...        ...         ...
# 826  MM843       70       Male       White
# 827  MM835       56       Male       White
# 828  MM836       46       Male       White
# 829  MM837       59       Male       White
# 830  MM838       53       Male       White
#
# [831 rows x 4 columns]

# %%
data['RacialGroup'].unique()
# Out:
# array(['White', 'Black', 'Asian', 'Not reported', 'Other'], dtype=object)

# %%
data['PatientSex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# First I just want to acknowledge that this method of encoding might be not so good, since we are imposing that somehow gender is comparable and male is greater than female (Male = 1, Female = 0). Later we can use one hot encoding or other better encoding mechanism. For now let's convert these strings to numbers first.

# %%
# given a age return its encoding:
# <= 69 -> 1, >=70 -> 0
def encodeAge(age):
  # not good idea to leave a magical number
  # like 69 but this is not software engineering
  # so it is okay..
  return 1 if age <= 69 else 0

# Male -> 1, Female -> 0
def encodeSex(sex):
  return 1 if sex == 'Male' else 0

# White -> 1, Black -> 2, Asian -> 3
# else -> 4
def encodeRace(race):
  if race == 'White':
    return 1
  elif race == 'Black':
    return 2
  elif race == 'Asian':
    return 3
  else:
    return 4

# %%
# apply encoding to Age column
data['AgeAtDx'] = data['AgeAtDx'].apply(encodeAge)

# %%
data
# Out:
#         ID  AgeAtDx PatientSex RacialGroup
# 0      MM1        1       Male       White
# 1      MM2        1       Male       Black
# 2      MM3        1       Male       White
# 3      MM4        1     Female       White
# 4      MM5        1       Male       White
# ..     ...      ...        ...         ...
# 826  MM843        0       Male       White
# 827  MM835        1       Male       White
# 828  MM836        1       Male       White
# 829  MM837        1       Male       White
# 830  MM838        1       Male       White
#
# [831 rows x 4 columns]

# %%
# apply encoding function to sex column
data['PatientSex'] = data['PatientSex'].apply(encodeSex)

# %%
# apply encoding function to race column
data['RacialGroup'] = data['RacialGroup'].apply(encodeRace)

# %%
data
# Out:
#         ID  AgeAtDx  PatientSex  RacialGroup
# 0      MM1        1           1            1
# 1      MM2        1           1            2
# 2      MM3        1           1            1
# 3      MM4        1           0            1
# 4      MM5        1           1            1
# ..     ...      ...         ...          ...
# 826  MM843        0           1            1
# 827  MM835        1           1            1
# 828  MM836        1           1            1
# 829  MM837        1           1            1
# 830  MM838        1           1            1
#
# [831 rows x 4 columns]

# %% [markdown]
# As we can see the transformed data looks like what we expected. Now let's save this dataframe.

# %%
data.to_csv('Demographics_encoded.csv', index = False)

# %% [markdown]
# # 3. prepare medications data

# %% [markdown]
# In this section we will prepare the medications data of each patient. By this I mean the 5 medicines: denosumab, pamidronate, zoledronate, calcium, vitamin D. We will have 5 columns denoting these 5 medicines. And the value in the cell will have a 1 if patient has taken this drug 90 days before STC, and 0 otherwise.
#
# Note: if patient didn't take any of the 5 medicines during 90 days before STC, look at the days before 90 days as well. If no data for this patient taking this medicine before STC date in Medications.csv, look at MyelomaTherapy.csv

# %%
data = pd.read_csv('MyelomaTherapy.csv')

# %%
data.head()
# Out:
#     ID             MedTx    Combination  ... Line Duration  TreatmentPhase
# 0  MM1        Bortezomib            VRD  ...    1    195.0       Induction
# 1  MM1     Dexamethasone            VRD  ...    1    195.0       Induction
# 2  MM1      Lenalidomide            VRD  ...    1    195.0       Induction
# 3  MM1  Cyclophosphamide  Not specified  ...    2     32.0       Induction
# 4  MM1     Dexamethasone  Not specified  ...    2     32.0       Induction
#
# [5 rows x 10 columns]

# %%
sorted(data['MedTx'].unique())
# Out:
# ['Adriamycin',
#  'Alpelisib',
#  'Anti-BCMA CAR-T',
#  'Anti-CD352',
#  'Anti-CD38',
#  'Anti-CD45',
#  'Anti-DKK1',
#  'Anti-FGFR3',
#  'Anti-Huluc63',
#  'Anti-PD1',
#  'Bendamustine',
#  'Bortezomib',
#  'Cabazitaxel',
#  'Carfilzomib',
#  'Carmustine',
#  'Cisplatin',
#  'Cyclophosphamide',
#  'Cytarabine',
#  'Daratumumab',
#  'Decitabine',
#  'Dexamethasone',
#  'Donor lymphocyte infusion',
#  'Doxorubicin',
#  'Doxorubicin ',
#  'Elotuzumab',
#  'Erlotinib',
#  'Etoposide',
#  'Filanesib',
#  'Fludarabine',
#  'G-CSF',
#  'GSK2857916',
#  'Gamma secretase inhibitor',
#  'Ibrutinib',
#  'Ifosfamide',
#  'Interferon',
#  'Interferon alpha',
#  'Isatuximab',
#  'Ixazomib',
#  'LGH447',
#  'Lenalidomide',
#  'Liposomal doxorubicin',
#  'Lucatumumab',
#  'MDX1338',
#  'Melphalan',
#  'Methotrexate',
#  'Methylprednisolone',
#  'Ofatumumab',
#  'Paciltaxel',
#  'Panobinostat',
#  'Pembrolizumab',
#  'Plerixafor',
#  'Pomalidomide',
#  'Prednisone',
#  'Ricolinostat',
#  'Rituximab',
#  'SEA-BCMA',
#  'SGN-CD352A',
#  'SNS01-T',
#  'Stem cell transplant',
#  'TTI-621',
#  'Thalidomide',
#  'Thiotepa',
#  'Ulocuplumab',
#  'Venetoclax',
#  'Vincristine',
#  'Vorinostat',
#  'Yttrium-90']

# %% [markdown]
# As we can see, for all the 5 medicines we consider, none of them are in the medication list in MyelomaTherapy.csv. So I guess we only need to look at Medications.csv

# %%
data = pd.read_csv('Medications.csv')

# %%
data
# Out:
#             ID                         Note  ...  NegationScore TermScore
# 0          MM7                    AdmitNote  ...            NaN  0.485489
# 1          MM7             SCCA-OutptRecord  ...            NaN  0.381300
# 2         MM55        Nutrition-OutptRecord  ...            NaN  0.406916
# 3         MM55        Nutrition-OutptRecord  ...            NaN  0.490309
# 4        MM416        Nutrition-OutptRecord  ...            NaN  0.350080
# ...        ...                          ...  ...            ...       ...
# 1303298  MM509         Neurology-InptRecord  ...            NaN  0.995776
# 1303299  MM455             SCCA-OutptRecord  ...            NaN  0.994309
# 1303300  MM455  PhysicalTherapy-OutptRecord  ...            NaN  0.975874
# 1303301  MM455             SCCA-OutptRecord  ...            NaN  0.991613
# 1303302  MM195              OperativeReport  ...            NaN  0.841065
#
# [1303303 rows x 9 columns]

# %% [markdown]
# reminder of the 5 medicines we are looking at: denosumab, pamidronate, zoledronate, calcium, vitamin D

# %%
len(data['Term'].unique())
# Out:
# 1348

# %%
sorted(data['Term'].unique()[1310:])
# Out:
# ['Verapamil',
#  'Vervain',
#  'Vilazodone',
#  'Vincristine',
#  'Vitamin',
#  'Vitamin D supplements',
#  'Vitamin supplement',
#  'Vitamin supplementation',
#  'Voriconazole',
#  'Vorinostat',
#  'Vortex',
#  'Warfarin',
#  'Warfarin sodium',
#  'White petrolatum',
#  'Witch hazel',
#  'Xylitol',
#  'Zafirlukast',
#  'Zaleplon',
#  'Zanamivir',
#  'Zeaxanthin',
#  'Zileuton',
#  'Zinc',
#  'Zinc acetate',
#  'Zinc chloride',
#  'Zinc gluconate',
#  'Zinc oxide',
#  'Zinc sulfate',
#  'Zinc supplement',
#  'Ziprasidone',
#  'Zoledronate',
#  'Zoledronic acid',
#  'Zolmitriptan',
#  'Zolpidem',
#  'Zolpidem tartrate',
#  'Zomepirac',
#  'Zonisamide',
#  'Zopiclone',
#  'Zymar']

# %% [markdown]
# Assume Vitamin D supplements means Vitamin D.

# %%
'Vitamin D supplements' in data['Term'].unique()
# Out:
# True

# %%
'Calcium' in data['Term'].unique()
# Out:
# True

# %%
'Denosumab' in data['Term'].unique()
# Out:
# True

# %%
'Pamidronate' in data['Term'].unique()
# Out:
# True

# %%
'Zoledronate' in data['Term'].unique()
# Out:
# True

# %%
'Dexamethasone' in data['Term'].unique()
# Out:
# True

# %%
# also need to include Dexamethasone.
# so there are actually 6 medicines we consider.
medicines = ['Vitamin D supplements', 'Calcium', 'Denosumab', 'Pamidronate', 'Zoledronate', 'Dexamethasone']

# %%
# the rows that contain the the ID + 6 other values
# indicating whether the patient took each medicine.
# for example one row might be ['MM1', 1, 0, 0, 0, 0, 0]
rows = []
progress = 0
for ID, STC_Day in patientToDayOfSTC.items():
  # the data of this patient 90 days prior to STC date
  this_patient_data = data[(data['ID'] == ID) & (data['DaysFromDx'] <= STC_Day) & (data['DaysFromDx'] >= STC_Day - 90)]
  # if this dataframe is empty, or that the medications in this 90 days prior
  # to STC date don't contain any of the 6 medicines we want information of
  # we look at the days even prior to 90 days.
  if this_patient_data.shape[0] == 0 or (not (any(item in this_patient_data['Term'].unique() for item in medicines))):
    this_patient_data = data[(data['ID'] == ID) & (data['DaysFromDx'] <= STC_Day)]

  thisRow = [ID] # put ID in this row first

  # for each medicine, if this medicine is in the dataframe
  # add 1 to our row, else add 0
  for medicine in medicines:
    if medicine in this_patient_data['Term'].unique():
      thisRow.append(1)
    else:
      thisRow.append(0)
  # add this row to rows
  rows.append(thisRow)
  progress += 1
  if (progress % 10 == 0):
    print(progress/len(patientToDayOfSTC))
# Out:
# 0.014245014245014245
# 0.02849002849002849
# 0.042735042735042736
# 0.05698005698005698
# 0.07122507122507123
# 0.08547008547008547
# 0.09971509971509972
# 0.11396011396011396
# 0.1282051282051282
# 0.14245014245014245
# 0.15669515669515668
# 0.17094017094017094
# 0.18518518518518517
# 0.19943019943019943
# 0.21367521367521367
# 0.22792022792022792
# 0.24216524216524216
# 0.2564102564102564
# 0.2706552706552707
# 0.2849002849002849
# 0.29914529914529914
# 0.31339031339031337
# 0.32763532763532766
# 0.3418803418803419
# 0.3561253561253561
# 0.37037037037037035
# 0.38461538461538464
# 0.39886039886039887
# 0.4131054131054131
# 0.42735042735042733
# 0.4415954415954416
# 0.45584045584045585
# 0.4700854700854701
# 0.4843304843304843
# 0.4985754985754986
# 0.5128205128205128
# 0.5270655270655271
# 0.5413105413105413
# 0.5555555555555556
# 0.5698005698005698
# 0.584045584045584
# 0.5982905982905983
# 0.6125356125356125
# 0.6267806267806267
# 0.6410256410256411
# 0.6552706552706553
# 0.6695156695156695
# 0.6837606837606838
# 0.698005698005698
# 0.7122507122507122
# 0.7264957264957265
# 0.7407407407407407
# 0.7549857549857549
# 0.7692307692307693
# 0.7834757834757835
# 0.7977207977207977
# 0.811965811965812
# 0.8262108262108262
# 0.8404558404558404
# 0.8547008547008547
# 0.8689458689458689
# 0.8831908831908832
# 0.8974358974358975
# 0.9116809116809117
# 0.9259259259259259
# 0.9401709401709402
# 0.9544159544159544
# 0.9686609686609686
# 0.9829059829059829
# 0.9971509971509972

# %%
len(rows)
# Out:
# 702

# %%
# convert rows to a dataframe.
df_medicines = pd.DataFrame(rows, columns = ['ID'] + medicines)

# %%
df_medicines.sum()
# Out:
# ID                       MM1MM2MM4MM5MM6MM7MM8MM10MM12MM13MM15MM953MM17...
# Vitamin D supplements                                                    1
# Calcium                                                                344
# Denosumab                                                                5
# Pamidronate                                                             52
# Zoledronate                                                              8
# Dexamethasone                                                          462
# dtype: object

# %% [markdown]
# As we can see, majority of people took Dexamethasone, which is expected.

# %%
df_medicines
# Out:
#         ID  Vitamin D supplements  ...  Zoledronate  Dexamethasone
# 0      MM1                      0  ...            0              1
# 1      MM2                      0  ...            0              1
# 2      MM4                      0  ...            0              1
# 3      MM5                      0  ...            0              0
# 4      MM6                      0  ...            0              1
# ..     ...                    ...  ...          ...            ...
# 697  MM834                      0  ...            0              0
# 698  MM843                      0  ...            0              0
# 699  MM836                      0  ...            0              1
# 700  MM837                      0  ...            0              1
# 701  MM838                      0  ...            0              0
#
# [702 rows x 7 columns]

# %%
# save dataframe to csv.
df_medicines.to_csv('medicines_90_days_before_STC.csv', index = False)

# %% [markdown]
# # 4. encode cancer stage

# %%
data = pd.read_csv('Stage.csv')

# %%
data
# Out:
#         ID StagingSystem Stage
# 0      MM2           ISS   III
# 1      MM3           ISS     I
# 2      MM4           ISS   III
# 3      MM5           ISS     I
# 4      MM6           ISS     I
# ..     ...           ...   ...
# 526  MM834           ISS     I
# 527  MM843           ISS    II
# 528  MM835           ISS     I
# 529  MM836           ISS    II
# 530  MM838           ISS    II
#
# [531 rows x 3 columns]

# %% [markdown]
# We want to encode stage I as 1, stage II as 2, and stage III as 3

# %%
def encodeStage(stage):
  if stage == 'I':
    return 1
  elif stage == 'II':
    return 2
  elif stage == 'III':
    return 3
  else:
    return None

# %%
 data['Stage'] = data['Stage'].apply(lambda x: encodeStage(x))

# %%
data
# Out:
#         ID StagingSystem  Stage
# 0      MM2           ISS      3
# 1      MM3           ISS      1
# 2      MM4           ISS      3
# 3      MM5           ISS      1
# 4      MM6           ISS      1
# ..     ...           ...    ...
# 526  MM834           ISS      1
# 527  MM843           ISS      2
# 528  MM835           ISS      1
# 529  MM836           ISS      2
# 530  MM838           ISS      2
#
# [531 rows x 3 columns]

# %%
# we only want the ID and stage columns
data = data[['ID', 'Stage']]

# %%
data
# Out:
#         ID  Stage
# 0      MM2      3
# 1      MM3      1
# 2      MM4      3
# 3      MM5      1
# 4      MM6      1
# ..     ...    ...
# 526  MM834      1
# 527  MM843      2
# 528  MM835      1
# 529  MM836      2
# 530  MM838      2
#
# [531 rows x 2 columns]

# %%
# save this to csv.
data.to_csv('Stages_encoded.csv', index = False)

# %% [markdown]
# # 5. encode Bony Lesions

# %%
data = pd.read_csv('BonyLesions.csv')

# %%
data
# Out:
#          ID DxType  DaysFromDx BonyLesions
# 0       MM1    MRI        22.0           0
# 1       MM1    MRI      2064.0           1
# 2       MM1    MRI       716.0           1
# 3       MM1    MRI       442.0          >3
# 4       MM1    MRI       251.0           0
# ...     ...    ...         ...         ...
# 3800  MM838    MRI      3773.0           0
# 3801  MM838    MRI      1687.0           0
# 3802  MM838    MRI      3773.0           0
# 3803  MM838    MRI       991.0           0
# 3804  MM838    MRI       320.0          >3
#
# [3805 rows x 4 columns]

# %%
data['BonyLesions'].unique()
# Out:
# array(['0', '1', '>3', '2'], dtype=object)

# %% [markdown]
# we decided to encode BonyLesions of '0' to 0, and '1', '2', '>3' to 1
#
# We will first look from the closest prior to STC day, if there is no data there, we will look after STC day as well.

# %%
df_lesions = pd.DataFrame(columns=data.columns)

# %%
df_lesions
# Out:
# Empty DataFrame
# Columns: [ID, DxType, DaysFromDx, BonyLesions]
# Index: []

# %%
for ID, STC_Day in patientToDayOfSTC.items():
  less_than_STC_data = data[(data['ID'] == ID) & (data['DaysFromDx'] <= STC_Day)]
  if less_than_STC_data.shape[0] == 0:
    greater_than_STC_data = data[(data['ID'] == ID) & (data['DaysFromDx'] > STC_Day)]
    if greater_than_STC_data.shape[0] != 0:
      df_lesions = df_lesions.append(greater_than_STC_data.sort_values(by = ['DaysFromDx']).iloc[0:1, :], ignore_index=True)
  else:
    df_lesions = df_lesions.append(less_than_STC_data.sort_values(by = ['DaysFromDx'], ascending = False).iloc[0:1, :], ignore_index=True)

# %%
df_lesions
# Out:
#         ID DxType  DaysFromDx BonyLesions
# 0      MM1    MRI       297.0           0
# 1      MM2    MRI       176.0          >3
# 2      MM4    MRI       411.0           1
# 3      MM5    MRI       373.0           0
# 4      MM7    MRI       197.0          >3
# ..     ...    ...         ...         ...
# 664  MM834    MRI       161.0          >3
# 665  MM843    MRI       812.0          >3
# 666  MM836    MRI       754.0          >3
# 667  MM837    MRI       173.0          >3
# 668  MM838    MRI       190.0          >3
#
# [669 rows x 4 columns]

# %% [markdown]
# let's check if we indeed get the correct result for patient MM1

# %%
data[data['ID'] == 'MM1'].sort_values(by = ['DaysFromDx'])
# Out:
#     ID DxType  DaysFromDx BonyLesions
# 0  MM1    MRI        22.0           0
# 4  MM1    MRI       251.0           0
# 5  MM1    MRI       297.0           0
# 7  MM1    MRI       428.0           2
# 3  MM1    MRI       442.0          >3
# 6  MM1    MRI       701.0          >3
# 2  MM1    MRI       716.0           1
# 1  MM1    MRI      2064.0           1

# %%
patientToDayOfSTC['MM1']
# Out:
# 343.0

# %% [markdown]
# We 297 is within 343 - 90, so that row should be selected, and indeed that is what's selected by our dataframe.

# %%
def encodeLesions(lesionsString):
  if lesionsString == '0':
    return 0
  else:
    return 1

# %%
df_lesions
# Out:
#         ID DxType  DaysFromDx BonyLesions
# 0      MM1    MRI       297.0           0
# 1      MM2    MRI       176.0          >3
# 2      MM4    MRI       411.0           1
# 3      MM5    MRI       373.0           0
# 4      MM7    MRI       197.0          >3
# ..     ...    ...         ...         ...
# 664  MM834    MRI       161.0          >3
# 665  MM843    MRI       812.0          >3
# 666  MM836    MRI       754.0          >3
# 667  MM837    MRI       173.0          >3
# 668  MM838    MRI       190.0          >3
#
# [669 rows x 4 columns]

# %%
df_lesions['BonyLesions'] = df_lesions['BonyLesions'].apply(encodeLesions)

# %%
df_lesions
# Out:
#         ID DxType  DaysFromDx  BonyLesions
# 0      MM1    MRI       297.0            0
# 1      MM2    MRI       176.0            1
# 2      MM4    MRI       411.0            1
# 3      MM5    MRI       373.0            0
# 4      MM7    MRI       197.0            1
# ..     ...    ...         ...          ...
# 664  MM834    MRI       161.0            1
# 665  MM843    MRI       812.0            1
# 666  MM836    MRI       754.0            1
# 667  MM837    MRI       173.0            1
# 668  MM838    MRI       190.0            1
#
# [669 rows x 4 columns]

# %%
# save this to csv.
df_lesions.to_csv('Lesions_encoded.csv', index=False)

# %% [markdown]
# # 6. prepare frature data

# %% [markdown]
# Ultimately we want to predict whether this patient has bone frature during the 365 days after stem cell transplant. This information is stored in the columns of `BillingCodes.csv`

# %%
data = pd.read_csv('BillingCodes.csv')

# %%
data
# Out:
#            ID  ...                                      CCSLevel3Name
# 0         MM1  ...                            Cancer of thyroid [36.]
# 1         MM1  ...                            Cancer of thyroid [36.]
# 2         MM1  ...                            Cancer of thyroid [36.]
# 3         MM1  ...  Other and unspecified metabolic; nutritional; ...
# 4         MM1  ...                          Allergic reactions [253.]
# ...       ...  ...                                                ...
# 365050  MM838  ...                                           No Value
# 365051  MM838  ...                             Multiple myeloma [40.]
# 365052  MM838  ...                                           No Value
# 365053  MM838  ...              Medical examination/evaluation [256.]
# 365054  MM838  ...                                           No Value
#
# [365055 rows x 8 columns]

# %%
# we think fracture will be one of the word in the string of
# DxDescription, CCSLevel1Name, CCSLevel2Name, CCSLevel3Name
# Let's get those rows where there any of the 4 columns
# contain the word 'fracture'.

# define a function such that given a row, return true if that row contains
# the word fracture in one of its 4 columns
def doesRowContainFracture(row):
  return (isinstance(row['DxDescription'], str) and 'Fracture'.lower() in row['DxDescription'].lower()) or \
         (isinstance(row['CCSLevel1Name'], str) and 'Fracture'.lower() in row['CCSLevel1Name'].lower()) or \
         (isinstance(row['CCSLevel2Name'], str) and 'Fracture'.lower() in row['CCSLevel2Name'].lower()) or \
         (isinstance(row['CCSLevel3Name'], str) and 'Fracture'.lower() in row['CCSLevel3Name'].lower())

# %%
doesRowContainFracture(data.iloc[0])
# Out:
# False

# %% [markdown]
# As we can see, row 0 does indeed not have fracture in 1 of the 4 columns. function seems be doing what it is supposed to.

# %%
# get rows with word fracture in them.
data_fracture = data[data.apply(doesRowContainFracture, axis = 1)]

# %%
num_patients_fracture = len(data_fracture['ID'].unique())
print(f'there are {num_patients_fracture} number of patients with fracture')
# Out:
# there are 383 number of patients with fracture

# %%
data_fracture
# Out:
#            ID  ...           CCSLevel3Name
# 469       MM2  ...  Other fractures [231.]
# 656       MM3  ...                No Value
# 657       MM3  ...                No Value
# 658       MM3  ...                No Value
# 740       MM4  ...                No Value
# ...       ...  ...                     ...
# 360199  MM843  ...  Other fractures [231.]
# 360421  MM843  ...  Other fractures [231.]
# 360447  MM843  ...  Other fractures [231.]
# 360478  MM843  ...  Other fractures [231.]
# 360492  MM843  ...  Other fractures [231.]
#
# [2078 rows x 8 columns]

# %%
data_fracture['DxDescription'].unique()
# Out:
# array(['Closed fracture of rib(s), unspecified',
#        'Pathological fracture, other site, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in neoplastic disease, other specified site, initial encounter for fracture',
#        'Personal history of (healed) traumatic fracture',
#        'Pathologic fracture of vertebrae',
#        'Pathologic fracture of other specified site',
#        'Closed fracture of T7-T12 level with complete lesion of cord',
#        'Age-related osteoporosis without current pathological fracture',
#        'Personal history of (healed) other pathological fracture',
#        'Personal history of pathologic fracture',
#        'Collapsed vertebra, not elsewhere classified, site unspecified, subsequent encounter for fracture with routine healing',
#        'Pathological fracture, other site, initial encounter for fracture',
#        'Unspecified fracture of left femur, initial encounter for closed fracture',
#        'Aftercare for healing pathologic fracture of vertebrae',
#        'Open wound of tooth (broken) (fractured) (due to trauma), without mention of complication',
#        'Closed fracture of dorsal [thoracic] vertebra without mention of spinal cord injury',
#        'Closed fracture of unspecified part of neck of femur',
#        'Nonunion of fracture', 'Closed fracture of two ribs',
#        'Closed fracture of lumbar vertebra without mention of spinal cord injury',
#        'Other displaced fracture of upper end of left humerus, initial encounter for closed fracture',
#        'Unspecified fracture of shaft of humerus, left arm, initial encounter for closed fracture',
#        'Collapsed vertebra, not elsewhere classified, thoracic region, initial encounter for fracture',
#        'Pathological fracture, left humerus, initial encounter for fracture',
#        'Pathological fracture, left humerus, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in neoplastic disease, left humerus, initial encounter for fracture',
#        'Pathological fracture in neoplastic disease, left humerus, sequela',
#        'Aftercare for healing traumatic fracture of lower arm',
#        'Aftercare for healing pathologic fracture of other bone',
#        'Closed fracture of seventh cervical vertebra',
#        'Pathologic fracture of humerus',
#        'Closed fracture of unspecified vertebral column without mention of spinal cord injury',
#        'Closed fracture of unspecified part of lower end of humerus',
#        'Pathologic fracture of neck of femur',
#        'Pathologic fracture of other specified part of femur',
#        'Other aftercare involving internal fixation device',
#        'Pathologic fracture, unspecified site',
#        'Collapsed vertebra, not elsewhere classified, lumbar region, initial encounter for fracture',
#        'Collapsed vertebra, not elsewhere classified, site unspecified, initial encounter for fracture',
#        'Collapsed vertebra, not elsewhere classified, lumbar region, subsequent encounter for fracture with routine healing',
#        'Unstable burst fracture of T9-T10 vertebra, subsequent encounter for fracture with routine healing',
#        'Wedge compression fracture of T11-T12 vertebra, subsequent encounter for fracture with routine healing',
#        'Wedge compression fracture of T11-T12 vertebra, subsequent encounter for fracture with delayed healing',
#        'Unstable burst fracture of T11-T12 vertebra, subsequent encounter for fracture with routine healing',
#        'Wedge compression fracture of first lumbar vertebra, subsequent encounter for fracture with routine healing',
#        'Stress fracture of other bone',
#        'Unspecified fracture of T5-T6 vertebra, initial encounter for closed fracture',
#        'Multiple fractures of ribs, unspecified side, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in neoplastic disease, other specified site, subsequent encounter for fracture with routine healing',
#        'Closed fracture of one rib',
#        'Other, multiple and ill-defined fractures of lower limb, closed',
#        'Fracture of one rib, right side, subsequent encounter for fracture with routine healing',
#        'Closed fracture of multiple ribs, unspecified',
#        'Fracture of unspecified bone, closed',
#        'Unspecified fracture of unspecified thoracic vertebra, subsequent encounter for fracture with delayed healing',
#        'Unspecified fracture of unspecified lumbar vertebra, subsequent encounter for fracture with delayed healing',
#        'Pathologic fracture of tibia or fibula',
#        'Closed fracture of second cervical vertebra',
#        'Closed fracture of unspecified part of humerus',
#        'Closed fracture of acetabulum',
#        'Collapsed vertebra, not elsewhere classified, thoracolumbar region, sequela of fracture',
#        'Other fracture of unspecified thoracic vertebra, initial encounter for closed fracture',
#        'Other osteoporosis without current pathological fracture',
#        'Closed fracture of acromial process of scapula',
#        'Aftercare for healing traumatic fracture of vertebrae',
#        'Pathological fracture, right femur, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in neoplastic disease, right femur, initial encounter for fracture',
#        'Closed fracture of clavicle, unspecified part',
#        'Closed fracture of sternum',
#        'Closed fracture of eight or more ribs',
#        'Unspecified fracture of left ischium, subsequent encounter for fracture with routine healing',
#        'Unspecified fracture of first thoracic vertebra, subsequent encounter for fracture with routine healing',
#        'Unspecified fracture of second thoracic vertebra, subsequent encounter for fracture with routine healing',
#        'Other specified fracture of left pubis, subsequent encounter for fracture with routine healing',
#        'Unspecified Zone III fracture of sacrum, subsequent encounter for fracture with routine healing',
#        'Unspecified fracture of sacrum, initial encounter for closed fracture',
#        'Stable burst fracture of first lumbar vertebra, initial encounter for closed fracture',
#        'Stable burst fracture of first lumbar vertebra, subsequent encounter for fracture with routine healing',
#        'Closed fracture of metatarsal bone(s)',
#        'Fracture of lateral malleolus, closed',
#        'Bimalleolar fracture, closed',
#        'Other and unspecified closed fractures of proximal end of radius (alone)',
#        'Closed fracture of shaft of clavicle',
#        'Closed fracture of acromial end of clavicle',
#        'Closed fracture of upper end of forearm, unspecified',
#        'Trimalleolar fracture, closed',
#        'Displaced fracture of lateral end of left clavicle, subsequent encounter for fracture with nonunion',
#        'Aftercare for healing traumatic fracture of other bone',
#        'Aftercare for healing traumatic fracture of lower leg',
#        'Multiple fractures of ribs, left side, subsequent encounter for fracture with routine healing',
#        'Displaced fracture of shaft of right clavicle, initial encounter for closed fracture',
#        'Pathological fracture, left radius, subsequent encounter for fracture with delayed healing',
#        'Pathological fracture in other disease, left shoulder, subsequent encounter for fracture with nonunion',
#        'Pathological fracture, right shoulder, subsequent encounter for fracture with routine healing',
#        'Pathological fracture, left radius, subsequent encounter for fracture with routine healing',
#        'Pathological fracture, right shoulder, initial encounter for fracture',
#        'Multiple fractures of ribs, unspecified side, initial encounter for closed fracture',
#        'Multiple open fractures of hand bones',
#        'Open fracture of phalanx or phalanges of hand, unspecified',
#        'Closed fracture of distal phalanx or phalanges of hand',
#        'Closed fracture of phalanx or phalanges of hand, unspecified',
#        'Open fracture of multiple sites of phalanx or phalanges of hand',
#        'Wedge compression fracture of first lumbar vertebra, initial encounter for closed fracture',
#        'Wedge compression fracture of third lumbar vertebra, initial encounter for closed fracture',
#        'Pathological fracture in other disease, right foot, initial encounter for fracture',
#        'Pathological fracture in neoplastic disease, hip, unspecified, sequela',
#        'Pathological fracture in neoplastic disease, right femur, sequela',
#        'Pathological fracture in neoplastic disease, pelvis, initial encounter for fracture',
#        'Pathological fracture, hip, unspecified, subsequent encounter for fracture with routine healing',
#        'Unspecified fracture of right acetabulum, initial encounter for closed fracture',
#        'Unspecified fracture of right acetabulum, subsequent encounter for fracture with routine healing',
#        'Unspecified fracture of right ischium, subsequent encounter for fracture with routine healing',
#        'Closed fracture of sacrum and coccyx without mention of spinal cord injury',
#        'Closed fracture of lumbar spine with spinal cord injury',
#        'Fracture, cause unspecified',
#        'Aftercare for healing pathologic fracture of upper arm',
#        'Closed fracture of unspecified bone(s) of foot [except toes]',
#        'Unspecified fracture of ankle, closed',
#        'Closed fracture of fifth cervical vertebra',
#        'Other closed fracture of upper end of humerus',
#        'Open fracture of greater tuberosity of humerus', 'Flail chest',
#        'Closed fracture of unspecified part of upper end of humerus',
#        'Closed fracture of three ribs', 'Closed fracture of five ribs',
#        'Closed fracture of greater tuberosity of humerus',
#        'Closed fracture of nasal bones',
#        'Closed fracture of base of skull without mention of intra cranial injury, unspecified state of consciousness',
#        'Closed fracture of base of skull without mention of intra cranial injury, with no loss of consciousness',
#        'Aftercare for healing traumatic fracture of upper arm',
#        'Collapsed vertebra, not elsewhere classified, sacral and sacrococcygeal region, subsequent encounter for fracture with routine healing',
#        'Closed fracture of lower end of femur, unspecified part',
#        'Unspecified fracture of lower end of left tibia, subsequent encounter for closed fracture with routine healing',
#        'Pathological fracture, unspecified site, subsequent encounter for fracture with routine healing',
#        'Other osteoporosis with current pathological fracture, vertebra(e), initial encounter for fracture',
#        'Age-related osteoporosis with current pathological fracture, right shoulder, subsequent encounter for fracture with routine healing',
#        'Age-related osteoporosis with current pathological fracture, vertebra(e), subsequent encounter for fracture with routine healing',
#        'Fracture of unspecified part of right clavicle, initial encounter for closed fracture',
#        'Other closed skull fracture without mention of intracranial injury, unspecified state of consciousness',
#        'Encounter for removal of internal fixation device',
#        'Displaced comminuted fracture of shaft of humerus, left arm, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in neoplastic disease, left humerus, subsequent encounter for fracture with nonunion',
#        'Closed unspecified fracture of pelvis',
#        'Closed fracture of surgical neck of humerus',
#        'Closed fracture of unspecified vertebral column with spinal cord injury',
#        'Closed fracture of astragalus',
#        'Closed fracture of shaft of fibula with tibia',
#        'Closed fracture of unspecified part of fibula alone',
#        'Closed fracture of upper end of fibula with tibia',
#        'Open fracture of shaft of femur',
#        'Late effect of fracture of lower extremities',
#        'Late effect of fracture of upper extremities',
#        'Open fracture of trochanteric section of neck of femur, unspecified',
#        'Closed fracture of shaft of radius with ulna',
#        'Closed fracture of shaft of humerus',
#        'Fracture of tooth (traumatic), initial encounter for closed fracture',
#        'Displaced fracture of fifth metatarsal bone, right foot, subsequent encounter for fracture with routine healing',
#        'Nondisplaced fracture of fifth metatarsal bone, right foot, initial encounter for closed fracture',
#        'Nondisplaced fracture of fifth metatarsal bone, right foot, subsequent encounter for fracture with routine healing',
#        'Personal history of traumatic fracture',
#        'Pathological fracture in neoplastic disease, right humerus, initial encounter for fracture',
#        'Pathological fracture, right humerus, subsequent encounter for fracture with routine healing',
#        'Closed fracture of unspecified part of femur',
#        'Stress fracture of shaft of femur',
#        'Fracture of one rib, left side, initial encounter for closed fracture',
#        'Displaced fracture of greater trochanter of left femur, initial encounter for closed fracture',
#        'Displaced fracture of greater trochanter of left femur, subsequent encounter for closed fracture with routine healing',
#        'Collapsed vertebra, not elsewhere classified, thoracic region, subsequent encounter for fracture with routine healing',
#        'Late effect of fracture of spine and trunk without mention of spinal cord lesion',
#        'Fracture of clavicle due to birth trauma',
#        'Follow-up examination, following treatment of healed fracture',
#        'Collapsed vertebra, not elsewhere classified, thoracic region, sequela of fracture',
#        'Unspecified fracture of second lumbar vertebra, subsequent encounter for fracture with routine healing',
#        'Multiple closed pelvic fractures with disruption of pelvic circle',
#        'Closed fracture of upper end of tibia alone',
#        'Closed fracture of intertrochanteric section of neck of femur',
#        'Closed fracture of pubis', 'Closed fracture of ilium',
#        'Aftercare for healing traumatic fracture of upper leg',
#        'Closed fracture of shaft of femur',
#        'Open fracture of head of radius',
#        'Other open fracture of lower end of humerus',
#        'Fracture of one rib, right side, sequela',
#        'Unspecified fracture of left lower leg, initial encounter for closed fracture',
#        'Unspecified fracture of T7-T8 vertebra, subsequent encounter for fracture with routine healing',
#        'Fracture of one rib, right side, initial encounter for closed fracture',
#        'Other fracture of T9-T10 vertebra, subsequent encounter for fracture with routine healing',
#        'Unspecified fracture of T11-T12 vertebra, subsequent encounter for fracture with routine healing',
#        'Wedge compression fracture of unspecified thoracic vertebra, subsequent encounter for fracture with routine healing',
#        'Wedge compression fracture of unspecified thoracic vertebra, initial encounter for closed fracture',
#        'Unspecified fracture of left patella, initial encounter for closed fracture',
#        'Unspecified fracture of first lumbar vertebra, subsequent encounter for fracture with routine healing',
#        'Pathological fracture, pelvis, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in neoplastic disease, left femur, sequela',
#        'Pathological fracture in neoplastic disease, left femur, initial encounter for fracture',
#        'Wedge compression fracture of second lumbar vertebra, subsequent encounter for fracture with routine healing',
#        'Collapsed vertebra, not elsewhere classified, thoracolumbar region, initial encounter for fracture',
#        'Closed fracture of intracapsular section of neck of femur, unspecified',
#        'Fractured dental restorative material with loss of material',
#        'Collapsed vertebra, not elsewhere classified, site unspecified, sequela of fracture',
#        'Unspecified fracture of unspecified lumbar vertebra, subsequent encounter for fracture with routine healing',
#        'Unspecified fracture of fourth lumbar vertebra, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in other disease, other site, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in other disease, other site, initial encounter for fracture',
#        'Unspecified fracture of sternum, subsequent encounter for fracture with routine healing',
#        'Unspecified fracture of T5-T6 vertebra, subsequent encounter for fracture with routine healing',
#        'Collapsed vertebra, not elsewhere classified, thoracic region, subsequent encounter for fracture with delayed healing',
#        'Stable burst fracture of first thoracic vertebra, subsequent encounter for fracture with routine healing',
#        'Other fracture of first thoracic vertebra, sequela',
#        'Unspecified fracture of second lumbar vertebra, initial encounter for closed fracture',
#        'Unspecified fracture of T9-T10 vertebra, subsequent encounter for fracture with routine healing',
#        'Unstable burst fracture of first lumbar vertebra, subsequent encounter for fracture with routine healing',
#        'Wedge compression fracture of third lumbar vertebra, subsequent encounter for fracture with routine healing',
#        'Collapsed vertebra, not elsewhere classified, thoracolumbar region, subsequent encounter for fracture with routine healing',
#        'Displaced fracture of left ulna styloid process, subsequent encounter for closed fracture with nonunion',
#        'Open fracture of acetabulum',
#        'Pathological fracture in neoplastic disease, left radius, initial encounter for fracture',
#        'Pathological fracture in neoplastic disease, left radius, sequela',
#        'Pathological fracture, left radius, initial encounter for fracture',
#        'Pathological fracture, left ulna, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in neoplastic disease, left ulna, initial encounter for fracture',
#        'Pathological fracture, unspecified ulna and radius, initial encounter for fracture',
#        'Unspecified fracture of the lower end of left radius, subsequent encounter for closed fracture with routine healing',
#        'Other extraarticular fracture of lower end of left radius, initial encounter for closed fracture',
#        'Unspecified fracture of the lower end of left radius, initial encounter for closed fracture',
#        'Unspecified fracture of lower end of left ulna, initial encounter for closed fracture',
#        'Other fractures of lower end of left radius, subsequent encounter for closed fracture with routine healing',
#        'Displaced fracture of left ulna styloid process, subsequent encounter for closed fracture with routine healing',
#        'Wedge compression fracture of T5-T6 vertebra, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in neoplastic disease, left femur, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in neoplastic disease, left humerus, subsequent encounter for fracture with routine healing',
#        'Wedge compression fracture of T11-T12 vertebra, initial encounter for closed fracture',
#        'Pathological fracture, left femur, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in other disease, other site, subsequent encounter for fracture with delayed healing',
#        'Pathological fracture, left femur, initial encounter for fracture',
#        'Displaced oblique fracture of shaft of left femur, subsequent encounter for closed fracture with routine healing',
#        'Unspecified fracture of lower end of left humerus, subsequent encounter for fracture with routine healing',
#        'Closed fracture of head of radius',
#        'Closed fracture of unspecified part of radius (alone)',
#        'Fracture of unspecified part of neck of right femur, sequela',
#        'Unspecified fracture of T11-T12 vertebra, initial encounter for closed fracture',
#        'Unspecified fracture of shaft of left femur, subsequent encounter for closed fracture with routine healing',
#        'Pathological fracture, unspecified site, initial encounter for fracture',
#        'Pathological fracture, right humerus, initial encounter for fracture',
#        'Multiple fractures of ribs, right side, initial encounter for closed fracture',
#        'Pathological fracture, left shoulder, initial encounter for fracture',
#        'Pathological fracture, right humerus, sequela',
#        'Pathological fracture, right femur, initial encounter for fracture',
#        'Pathological fracture in neoplastic disease, right shoulder, initial encounter for fracture',
#        'Pathological fracture in neoplastic disease, right humerus, subsequent encounter for fracture with routine healing',
#        'Pathological fracture in neoplastic disease, unspecified humerus, subsequent encounter for fracture with routine healing',
#        'Unspecified trochanteric fracture of left femur, initial encounter for closed fracture',
#        'Displaced fracture of greater tuberosity of left humerus, subsequent encounter for fracture with routine healing',
#        'Unspecified nondisplaced fracture of fifth cervical vertebra, initial encounter for closed fracture',
#        'Unspecified fracture of unspecified thoracic vertebra, initial encounter for closed fracture',
#        'Wedge compression fracture of T7-T8 vertebra, subsequent encounter for fracture with routine healing',
#        'Closed fracture of malar and maxillary bones',
#        'Displaced comminuted fracture of shaft of humerus, right arm, subsequent encounter for fracture with routine healing',
#        'Unspecified fracture of shaft of humerus, right arm, initial encounter for closed fracture',
#        'Closed fracture of shaft of radius or ulna, unspecified',
#        'Ill-defined closed fractures of upper limb',
#        "Closed Monteggia's fracture",
#        'Closed fracture of coronoid process of ulna',
#        'Closed fracture of olecranon process of ulna',
#        'Displaced intertrochanteric fracture of right femur, subsequent encounter for closed fracture with routine healing',
#        'Displaced intertrochanteric fracture of right femur, initial encounter for closed fracture',
#        'Wedge compression fracture of fourth lumbar vertebra, subsequent encounter for fracture with routine healing',
#        'Other fracture of fourth lumbar vertebra, subsequent encounter for fracture with delayed healing'],
#       dtype=object)

# %%
# print all rows with description "Encounter for removal of internal fixation device"
data_fracture[data_fracture['DxDescription'].apply(lambda x: 'encounter for removal of internal fixation device' in x.lower())]
# Out:
#            ID  DaysFromDx  ... CCSLevel2Name           CCSLevel3Name
# 118531  MM206        1214  ...     Fractures  Other fractures [231.]
# 353751  MM828       -1542  ...     Fractures  Other fractures [231.]
#
# [2 rows x 8 columns]

# %%
# delete these 2 rows from dataframe
data_fracture = data_fracture[data_fracture['DxDescription'].apply(lambda x: 'encounter for removal of internal fixation device' not in x.lower())]

# %%
data_fracture.shape
# Out:
# (2076, 8)

# %% [markdown]
# 2078 (original dataframe size) - 2 (current dataframe size) = 2076, so we have indeed deleted 2 rows

# %%
data_fracture[data_fracture['DxDescription'].apply(lambda x: 'follow-up examination, following treatment of healed fracture' in x.lower())]
# Out:
#            ID  DaysFromDx  ... CCSLevel2Name           CCSLevel3Name
# 207131  MM396         482  ...     Fractures  Other fractures [231.]
# 359003  MM834         643  ...     Fractures  Other fractures [231.]
#
# [2 rows x 8 columns]

# %%
data_fracture = data_fracture[data_fracture['DxDescription'].apply(lambda x: 'follow-up examination, following treatment of healed fracture' not in x.lower())]

# %%
data_fracture.shape
# Out:
# (2074, 8)

# %%
data_fracture[data_fracture['DxDescription'].apply(lambda x: 'open wound of tooth (broken) (fractured) (due to trauma), without mention of complication' in x.lower())]
# Out:
#            ID  ...                                CCSLevel3Name
# 6235     MM12  ...  Open wounds of head; neck; and trunk [235.]
# 9868     MM20  ...  Open wounds of head; neck; and trunk [235.]
# 12499    MM22  ...  Open wounds of head; neck; and trunk [235.]
# 31079    MM55  ...  Open wounds of head; neck; and trunk [235.]
# 41925   MM867  ...  Open wounds of head; neck; and trunk [235.]
# 48116    MM73  ...  Open wounds of head; neck; and trunk [235.]
# 111845  MM195  ...  Open wounds of head; neck; and trunk [235.]
# 111981  MM195  ...  Open wounds of head; neck; and trunk [235.]
# 134776  MM239  ...  Open wounds of head; neck; and trunk [235.]
# 223026  MM434  ...  Open wounds of head; neck; and trunk [235.]
# 224445  MM438  ...  Open wounds of head; neck; and trunk [235.]
# 244064  MM474  ...  Open wounds of head; neck; and trunk [235.]
# 258140  MM514  ...  Open wounds of head; neck; and trunk [235.]
# 260105  MM520  ...  Open wounds of head; neck; and trunk [235.]
# 265373  MM535  ...  Open wounds of head; neck; and trunk [235.]
# 275021  MM560  ...  Open wounds of head; neck; and trunk [235.]
# 351700  MM855  ...  Open wounds of head; neck; and trunk [235.]
#
# [17 rows x 8 columns]

# %%
data_fracture[data_fracture['DxDescription'].apply(lambda x: 'open wound of tooth (broken) (fractured) (due to trauma), without mention of complication' in x.lower())].shape[0]
# Out:
# 17

# %%
data_fracture = data_fracture[data_fracture['DxDescription'].apply(lambda x: 'open wound of tooth (broken) (fractured) (due to trauma), without mention of complication' not in x.lower())]

# %%
data_fracture.shape
# Out:
# (2057, 8)

# %%
data_fracture[data_fracture['DxDescription'].apply(lambda x: 'other aftercare involving internal fixation device' in x.lower())].shape[0]
# Out:
# 18

# %%
data_fracture = data_fracture[data_fracture['DxDescription'].apply(lambda x: 'other aftercare involving internal fixation device' not in x.lower())]

# %%
data_fracture.shape
# Out:
# (2039, 8)

# %%
data_fracture[data_fracture['DxDescription'].apply(lambda x: 'other osteoporosis without current pathological fracture' in x.lower())].shape[0]
# Out:
# 50

# %%
data_fracture = data_fracture[data_fracture['DxDescription'].apply(lambda x: 'other osteoporosis without current pathological fracture' not in x.lower())]

# %%
data_fracture.shape
# Out:
# (1989, 8)

# %%
data_fracture = data_fracture[data_fracture['DxDescription'].apply(lambda x: 'osteoporosis without current pathological fracture' not in x.lower())]

# %%
data_fracture.shape
# Out:
# (1831, 8)

# %%
data_fracture[data_fracture['DxDescription'].apply(lambda x: 'tooth fracture' in x.lower())]
# Out:
# Empty DataFrame
# Columns: [ID, DaysFromDx, DxCodingMethod, DxCode, DxDescription, CCSLevel1Name, CCSLevel2Name, CCSLevel3Name]
# Index: []

# %%
data_fracture[data_fracture['DxDescription'].apply(lambda x: 'tooth' in x.lower())]
# Out:
#            ID  DaysFromDx  ... CCSLevel2Name CCSLevel3Name
# 147249  MM274        3577  ...     Fractures      No Value
#
# [1 rows x 8 columns]

# %%
data_fracture[data_fracture['DxDescription'].apply(lambda x: 'tooth' in x.lower())].iloc[0]['DxDescription']
# Out:
# 'Fracture of tooth (traumatic), initial encounter for closed fracture'

# %% [markdown]
# Does this count as 'tooth fracture'? I guess it does, so let's delete that.

# %%
data_fracture = data_fracture[data_fracture['DxDescription'].apply(lambda x: 'tooth' not in x.lower())]

# %%
data_fracture.shape
# Out:
# (1830, 8)

# %%
len(data_fracture['ID'].unique())
# Out:
# 351

# %%
data_fracture[data_fracture['CCSLevel1Name'].apply(lambda x: 'injury and poisoning' in x.lower())]
# Out:
#            ID  ...           CCSLevel3Name
# 469       MM2  ...  Other fractures [231.]
# 740       MM4  ...                No Value
# 741       MM4  ...                No Value
# 742       MM4  ...                No Value
# 2507      MM7  ...                No Value
# ...       ...  ...                     ...
# 360199  MM843  ...  Other fractures [231.]
# 360421  MM843  ...  Other fractures [231.]
# 360447  MM843  ...  Other fractures [231.]
# 360478  MM843  ...  Other fractures [231.]
# 360492  MM843  ...  Other fractures [231.]
#
# [717 rows x 8 columns]

# %%
for description in data_fracture[data_fracture['CCSLevel1Name'].apply(lambda x: 'injury and poisoning' in x.lower())]['DxDescription'].unique():
  print(description)
# Out:
# Closed fracture of rib(s), unspecified
# Personal history of (healed) traumatic fracture
# Closed fracture of T7-T12 level with complete lesion of cord
# Collapsed vertebra, not elsewhere classified, site unspecified, subsequent encounter for fracture with routine healing
# Unspecified fracture of left femur, initial encounter for closed fracture
# Aftercare for healing pathologic fracture of vertebrae
# Closed fracture of dorsal [thoracic] vertebra without mention of spinal cord injury
# Closed fracture of unspecified part of neck of femur
# Closed fracture of two ribs
# Closed fracture of lumbar vertebra without mention of spinal cord injury
# Other displaced fracture of upper end of left humerus, initial encounter for closed fracture
# Unspecified fracture of shaft of humerus, left arm, initial encounter for closed fracture
# Collapsed vertebra, not elsewhere classified, thoracic region, initial encounter for fracture
# Aftercare for healing traumatic fracture of lower arm
# Aftercare for healing pathologic fracture of other bone
# Closed fracture of seventh cervical vertebra
# Closed fracture of unspecified vertebral column without mention of spinal cord injury
# Closed fracture of unspecified part of lower end of humerus
# Collapsed vertebra, not elsewhere classified, lumbar region, initial encounter for fracture
# Collapsed vertebra, not elsewhere classified, site unspecified, initial encounter for fracture
# Collapsed vertebra, not elsewhere classified, lumbar region, subsequent encounter for fracture with routine healing
# Unstable burst fracture of T9-T10 vertebra, subsequent encounter for fracture with routine healing
# Wedge compression fracture of T11-T12 vertebra, subsequent encounter for fracture with routine healing
# Wedge compression fracture of T11-T12 vertebra, subsequent encounter for fracture with delayed healing
# Unstable burst fracture of T11-T12 vertebra, subsequent encounter for fracture with routine healing
# Wedge compression fracture of first lumbar vertebra, subsequent encounter for fracture with routine healing
# Unspecified fracture of T5-T6 vertebra, initial encounter for closed fracture
# Multiple fractures of ribs, unspecified side, subsequent encounter for fracture with routine healing
# Closed fracture of one rib
# Other, multiple and ill-defined fractures of lower limb, closed
# Fracture of one rib, right side, subsequent encounter for fracture with routine healing
# Closed fracture of multiple ribs, unspecified
# Fracture of unspecified bone, closed
# Unspecified fracture of unspecified thoracic vertebra, subsequent encounter for fracture with delayed healing
# Unspecified fracture of unspecified lumbar vertebra, subsequent encounter for fracture with delayed healing
# Closed fracture of second cervical vertebra
# Closed fracture of unspecified part of humerus
# Closed fracture of acetabulum
# Collapsed vertebra, not elsewhere classified, thoracolumbar region, sequela of fracture
# Other fracture of unspecified thoracic vertebra, initial encounter for closed fracture
# Closed fracture of acromial process of scapula
# Aftercare for healing traumatic fracture of vertebrae
# Closed fracture of clavicle, unspecified part
# Closed fracture of sternum
# Closed fracture of eight or more ribs
# Unspecified fracture of left ischium, subsequent encounter for fracture with routine healing
# Unspecified fracture of first thoracic vertebra, subsequent encounter for fracture with routine healing
# Unspecified fracture of second thoracic vertebra, subsequent encounter for fracture with routine healing
# Other specified fracture of left pubis, subsequent encounter for fracture with routine healing
# Unspecified Zone III fracture of sacrum, subsequent encounter for fracture with routine healing
# Unspecified fracture of sacrum, initial encounter for closed fracture
# Stable burst fracture of first lumbar vertebra, initial encounter for closed fracture
# Stable burst fracture of first lumbar vertebra, subsequent encounter for fracture with routine healing
# Closed fracture of metatarsal bone(s)
# Fracture of lateral malleolus, closed
# Bimalleolar fracture, closed
# Other and unspecified closed fractures of proximal end of radius (alone)
# Closed fracture of shaft of clavicle
# Closed fracture of acromial end of clavicle
# Closed fracture of upper end of forearm, unspecified
# Trimalleolar fracture, closed
# Displaced fracture of lateral end of left clavicle, subsequent encounter for fracture with nonunion
# Aftercare for healing traumatic fracture of other bone
# Aftercare for healing traumatic fracture of lower leg
# Multiple fractures of ribs, left side, subsequent encounter for fracture with routine healing
# Displaced fracture of shaft of right clavicle, initial encounter for closed fracture
# Multiple fractures of ribs, unspecified side, initial encounter for closed fracture
# Multiple open fractures of hand bones
# Open fracture of phalanx or phalanges of hand, unspecified
# Closed fracture of distal phalanx or phalanges of hand
# Closed fracture of phalanx or phalanges of hand, unspecified
# Open fracture of multiple sites of phalanx or phalanges of hand
# Wedge compression fracture of first lumbar vertebra, initial encounter for closed fracture
# Wedge compression fracture of third lumbar vertebra, initial encounter for closed fracture
# Unspecified fracture of right acetabulum, initial encounter for closed fracture
# Unspecified fracture of right acetabulum, subsequent encounter for fracture with routine healing
# Unspecified fracture of right ischium, subsequent encounter for fracture with routine healing
# Closed fracture of sacrum and coccyx without mention of spinal cord injury
# Closed fracture of lumbar spine with spinal cord injury
# Aftercare for healing pathologic fracture of upper arm
# Closed fracture of unspecified bone(s) of foot [except toes]
# Unspecified fracture of ankle, closed
# Closed fracture of fifth cervical vertebra
# Other closed fracture of upper end of humerus
# Open fracture of greater tuberosity of humerus
# Flail chest
# Closed fracture of unspecified part of upper end of humerus
# Closed fracture of three ribs
# Closed fracture of five ribs
# Closed fracture of greater tuberosity of humerus
# Closed fracture of nasal bones
# Closed fracture of base of skull without mention of intra cranial injury, unspecified state of consciousness
# Closed fracture of base of skull without mention of intra cranial injury, with no loss of consciousness
# Aftercare for healing traumatic fracture of upper arm
# Collapsed vertebra, not elsewhere classified, sacral and sacrococcygeal region, subsequent encounter for fracture with routine healing
# Closed fracture of lower end of femur, unspecified part
# Unspecified fracture of lower end of left tibia, subsequent encounter for closed fracture with routine healing
# Fracture of unspecified part of right clavicle, initial encounter for closed fracture
# Other closed skull fracture without mention of intracranial injury, unspecified state of consciousness
# Displaced comminuted fracture of shaft of humerus, left arm, subsequent encounter for fracture with routine healing
# Closed unspecified fracture of pelvis
# Closed fracture of surgical neck of humerus
# Closed fracture of unspecified vertebral column with spinal cord injury
# Closed fracture of astragalus
# Closed fracture of shaft of fibula with tibia
# Closed fracture of unspecified part of fibula alone
# Closed fracture of upper end of fibula with tibia
# Open fracture of shaft of femur
# Late effect of fracture of lower extremities
# Late effect of fracture of upper extremities
# Open fracture of trochanteric section of neck of femur, unspecified
# Closed fracture of shaft of radius with ulna
# Closed fracture of shaft of humerus
# Displaced fracture of fifth metatarsal bone, right foot, subsequent encounter for fracture with routine healing
# Nondisplaced fracture of fifth metatarsal bone, right foot, initial encounter for closed fracture
# Nondisplaced fracture of fifth metatarsal bone, right foot, subsequent encounter for fracture with routine healing
# Personal history of traumatic fracture
# Closed fracture of unspecified part of femur
# Fracture of one rib, left side, initial encounter for closed fracture
# Displaced fracture of greater trochanter of left femur, initial encounter for closed fracture
# Displaced fracture of greater trochanter of left femur, subsequent encounter for closed fracture with routine healing
# Collapsed vertebra, not elsewhere classified, thoracic region, subsequent encounter for fracture with routine healing
# Late effect of fracture of spine and trunk without mention of spinal cord lesion
# Collapsed vertebra, not elsewhere classified, thoracic region, sequela of fracture
# Unspecified fracture of second lumbar vertebra, subsequent encounter for fracture with routine healing
# Multiple closed pelvic fractures with disruption of pelvic circle
# Closed fracture of upper end of tibia alone
# Closed fracture of intertrochanteric section of neck of femur
# Closed fracture of pubis
# Closed fracture of ilium
# Aftercare for healing traumatic fracture of upper leg
# Closed fracture of shaft of femur
# Open fracture of head of radius
# Other open fracture of lower end of humerus
# Fracture of one rib, right side, sequela
# Unspecified fracture of left lower leg, initial encounter for closed fracture
# Unspecified fracture of T7-T8 vertebra, subsequent encounter for fracture with routine healing
# Fracture of one rib, right side, initial encounter for closed fracture
# Other fracture of T9-T10 vertebra, subsequent encounter for fracture with routine healing
# Unspecified fracture of T11-T12 vertebra, subsequent encounter for fracture with routine healing
# Wedge compression fracture of unspecified thoracic vertebra, subsequent encounter for fracture with routine healing
# Wedge compression fracture of unspecified thoracic vertebra, initial encounter for closed fracture
# Unspecified fracture of left patella, initial encounter for closed fracture
# Unspecified fracture of first lumbar vertebra, subsequent encounter for fracture with routine healing
# Wedge compression fracture of second lumbar vertebra, subsequent encounter for fracture with routine healing
# Collapsed vertebra, not elsewhere classified, thoracolumbar region, initial encounter for fracture
# Closed fracture of intracapsular section of neck of femur, unspecified
# Collapsed vertebra, not elsewhere classified, site unspecified, sequela of fracture
# Unspecified fracture of unspecified lumbar vertebra, subsequent encounter for fracture with routine healing
# Unspecified fracture of fourth lumbar vertebra, subsequent encounter for fracture with routine healing
# Unspecified fracture of sternum, subsequent encounter for fracture with routine healing
# Unspecified fracture of T5-T6 vertebra, subsequent encounter for fracture with routine healing
# Collapsed vertebra, not elsewhere classified, thoracic region, subsequent encounter for fracture with delayed healing
# Stable burst fracture of first thoracic vertebra, subsequent encounter for fracture with routine healing
# Other fracture of first thoracic vertebra, sequela
# Unspecified fracture of second lumbar vertebra, initial encounter for closed fracture
# Unspecified fracture of T9-T10 vertebra, subsequent encounter for fracture with routine healing
# Unstable burst fracture of first lumbar vertebra, subsequent encounter for fracture with routine healing
# Wedge compression fracture of third lumbar vertebra, subsequent encounter for fracture with routine healing
# Collapsed vertebra, not elsewhere classified, thoracolumbar region, subsequent encounter for fracture with routine healing
# Displaced fracture of left ulna styloid process, subsequent encounter for closed fracture with nonunion
# Open fracture of acetabulum
# Unspecified fracture of the lower end of left radius, subsequent encounter for closed fracture with routine healing
# Other extraarticular fracture of lower end of left radius, initial encounter for closed fracture
# Unspecified fracture of the lower end of left radius, initial encounter for closed fracture
# Unspecified fracture of lower end of left ulna, initial encounter for closed fracture
# Other fractures of lower end of left radius, subsequent encounter for closed fracture with routine healing
# Displaced fracture of left ulna styloid process, subsequent encounter for closed fracture with routine healing
# Wedge compression fracture of T5-T6 vertebra, subsequent encounter for fracture with routine healing
# Wedge compression fracture of T11-T12 vertebra, initial encounter for closed fracture
# Displaced oblique fracture of shaft of left femur, subsequent encounter for closed fracture with routine healing
# Unspecified fracture of lower end of left humerus, subsequent encounter for fracture with routine healing
# Closed fracture of head of radius
# Closed fracture of unspecified part of radius (alone)
# Fracture of unspecified part of neck of right femur, sequela
# Unspecified fracture of T11-T12 vertebra, initial encounter for closed fracture
# Unspecified fracture of shaft of left femur, subsequent encounter for closed fracture with routine healing
# Multiple fractures of ribs, right side, initial encounter for closed fracture
# Unspecified trochanteric fracture of left femur, initial encounter for closed fracture
# Displaced fracture of greater tuberosity of left humerus, subsequent encounter for fracture with routine healing
# Unspecified nondisplaced fracture of fifth cervical vertebra, initial encounter for closed fracture
# Unspecified fracture of unspecified thoracic vertebra, initial encounter for closed fracture
# Wedge compression fracture of T7-T8 vertebra, subsequent encounter for fracture with routine healing
# Closed fracture of malar and maxillary bones
# Displaced comminuted fracture of shaft of humerus, right arm, subsequent encounter for fracture with routine healing
# Unspecified fracture of shaft of humerus, right arm, initial encounter for closed fracture
# Closed fracture of shaft of radius or ulna, unspecified
# Ill-defined closed fractures of upper limb
# Closed Monteggia's fracture
# Closed fracture of coronoid process of ulna
# Closed fracture of olecranon process of ulna
# Displaced intertrochanteric fracture of right femur, subsequent encounter for closed fracture with routine healing
# Displaced intertrochanteric fracture of right femur, initial encounter for closed fracture
# Wedge compression fracture of fourth lumbar vertebra, subsequent encounter for fracture with routine healing
# Other fracture of fourth lumbar vertebra, subsequent encounter for fracture with delayed healing

# %% [markdown]
# Should we delete the rows with `'injury and poisoning'` as the CCSLevel1 description? It makes sense to delete them because we don't want to count the fracture from personal injuries, we want the ones that arises from cancer. **Consult Emisa later**. Based on my decision, I think we should delete those rows.

# %%
data_fracture = data_fracture[data_fracture['CCSLevel1Name'].apply(lambda x: 'injury and poisoning' not in x.lower())]

# %%
data_fracture.shape
# Out:
# (1113, 8)

# %% [markdown]
# Now we have deleted all the fractures that are not pathological fractures, let's make a dictionary that maps a patient's ID to whether he/she had fracture during 1 year after STC treatment.

# %%
data_fracture[data_fracture['ID'] == 'MM852']
# Out:
#           ID  DaysFromDx  ...                 CCSLevel2Name CCSLevel3Name
# 37558  MM852         882  ...  Pathological fracture [207.]      No Value
#
# [1 rows x 8 columns]

# %%
fractureList = [] # list of mappings from ID to 0 or 1 based on if this patient has fracture
for ID in patientToDayOfSTC.keys(): # for every patient who took STC:
  if ID not in data_fracture['ID'].unique(): # if they are not in the dataframe
    # it means they don't have fracture after STC. put 0 there
    fractureList.append([ID, 0])
  else:
    # get their dataframe
    patient_df = data_fracture[data_fracture['ID'] == ID]
    # if that dataframe contain any row that has date during 1 year after STC,
    # put 1 there
    if patient_df[(patient_df['DaysFromDx'] >= patientToDayOfSTC[ID]) & (patient_df['DaysFromDx'] <= patientToDayOfSTC[ID] + 365)].shape[0] != 0:
      fractureList.append([ID, 1])
    else:
      # means patient does have fracture but not within a year after STC, put 0.
      fractureList.append([ID, 0])

# %%
# make a dataframe out of list:
df_result = pd.DataFrame(data = fractureList, columns= ['ID', 'HasFracture?'])

# %%
df_result
# Out:
#         ID  HasFracture?
# 0      MM1             0
# 1      MM2             0
# 2      MM4             0
# 3      MM5             0
# 4      MM6             0
# ..     ...           ...
# 697  MM834             0
# 698  MM843             0
# 699  MM836             0
# 700  MM837             0
# 701  MM838             0
#
# [702 rows x 2 columns]

# %%
df_result['HasFracture?'].sum()
# Out:
# 104

# %% [markdown]
# So we have 104 patients out of 700 with fracture within 1 year after STC it seems like

# %% [markdown]
# Should verify if our results are correct by checking if our results match the original dataset of data_fracture

# %%
df_result[df_result['HasFracture?'] == 1]
# Out:
#         ID  HasFracture?
# 5      MM7             1
# 6      MM8             1
# 10    MM15             1
# 31    MM39             1
# 46    MM53             1
# ..     ...           ...
# 665  MM788             1
# 667  MM914             1
# 671  MM805             1
# 691  MM828             1
# 695  MM930             1
#
# [104 rows x 2 columns]

# %%
data_fracture[data_fracture['ID'] == 'MM7'].sort_values(by = ['DaysFromDx'])
# Out:
#        ID  DaysFromDx  ...                 CCSLevel2Name CCSLevel3Name
# 2283  MM7           5  ...  Pathological fracture [207.]      No Value
# 2293  MM7           6  ...  Pathological fracture [207.]      No Value
# 2282  MM7           7  ...  Pathological fracture [207.]      No Value
# 2286  MM7           8  ...  Pathological fracture [207.]      No Value
# 2287  MM7          26  ...  Pathological fracture [207.]      No Value
# 2284  MM7         153  ...  Pathological fracture [207.]      No Value
# 2290  MM7         200  ...  Pathological fracture [207.]      No Value
# 2292  MM7         201  ...  Pathological fracture [207.]      No Value
# 2288  MM7         209  ...  Pathological fracture [207.]      No Value
# 2294  MM7         210  ...  Pathological fracture [207.]      No Value
# 2289  MM7         235  ...  Pathological fracture [207.]      No Value
# 3490  MM7         258  ...  Pathological fracture [207.]      No Value
# 3489  MM7         259  ...  Pathological fracture [207.]      No Value
# 2291  MM7         453  ...  Pathological fracture [207.]      No Value
# 2285  MM7         574  ...  Pathological fracture [207.]      No Value
# 2295  MM7         985  ...  Pathological fracture [207.]      No Value
# 3414  MM7        1688  ...  Pathological fracture [207.]      No Value
#
# [17 rows x 8 columns]

# %%
patientToDayOfSTC['MM7']
# Out:
# 203.0

# %% [markdown]
# We see that MM7 does indeed has a fracture 1 year after day 203, which our result includes a 1 for. seems like our process is correct.

# %%
# save dataframe to csv.
df_result.to_csv('Fractures.csv', index = False)

# %% [markdown]
# # 7. put every piece of data of a patient together

# %% [markdown]
# Now that we have processed and prepared individual piece of information of each patient. (lesions, demographics, fracture) Let's put them into a global dataframe

# %%
ls
# Out:
# BillingCodes.csv          Labs.csv                          Signs.csv
# BonyLesions.csv           Lesions_encoded.csv               Stage.csv
# Demographics.csv          Medications.csv                   Stages_encoded.csv
# Demographics_encoded.csv  medicines_90_days_before_STC.csv  SurvivalDays.csv
# Diagnoses.csv             MyelomaTherapy.csv                Symptoms.csv
# Fractures.csv             PlasmaCells.csv
# Labs_closest_to_SCT.csv   RadiationTherapy.csv

# %%
data_labs = pd.read_csv('Labs_closest_to_SCT.csv')
data_demographics = pd.read_csv('Demographics_encoded.csv')
data_medications = pd.read_csv('medicines_90_days_before_STC.csv')
data_cancer_stage = pd.read_csv('Stages_encoded.csv')
data_bony_lesions = pd.read_csv('Lesions_encoded.csv')
data_fracture = pd.read_csv('Fractures.csv')

# %%
data_labs
# Out:
#          ID ObservationId  ... LowerLimit UpperLimit
# 0       MM1            CA  ...        8.9       10.2
# 1       MM1             P  ...        2.5        4.5
# 2       MM1           ALK  ...       36.0      161.0
# 3       MM1         VITD3  ...       20.0      100.0
# 4       MM1          TEST  ...        1.6        5.9
# ...     ...           ...  ...        ...        ...
# 5254  MM838         VITD3  ...       20.0      100.0
# 5255  MM838          TEST  ...        1.6        5.9
# 5256  MM838           TSH  ...        0.4        5.0
# 5257  MM838           CRE  ...        0.3        1.2
# 5258  MM838         HSCRP  ...        0.0       10.0
#
# [5259 rows x 10 columns]

# %%
data_demographics
# Out:
#         ID  AgeAtDx  PatientSex  RacialGroup
# 0      MM1        1           1            1
# 1      MM2        1           1            2
# 2      MM3        1           1            1
# 3      MM4        1           0            1
# 4      MM5        1           1            1
# ..     ...      ...         ...          ...
# 826  MM843        0           1            1
# 827  MM835        1           1            1
# 828  MM836        1           1            1
# 829  MM837        1           1            1
# 830  MM838        1           1            1
#
# [831 rows x 4 columns]

# %%
data_medications
# Out:
#         ID  Vitamin D supplements  ...  Zoledronate  Dexamethasone
# 0      MM1                      0  ...            0              1
# 1      MM2                      0  ...            0              1
# 2      MM4                      0  ...            0              1
# 3      MM5                      0  ...            0              0
# 4      MM6                      0  ...            0              1
# ..     ...                    ...  ...          ...            ...
# 697  MM834                      0  ...            0              0
# 698  MM843                      0  ...            0              0
# 699  MM836                      0  ...            0              1
# 700  MM837                      0  ...            0              1
# 701  MM838                      0  ...            0              0
#
# [702 rows x 7 columns]

# %%
data_cancer_stage
# Out:
#         ID  Stage
# 0      MM2      3
# 1      MM3      1
# 2      MM4      3
# 3      MM5      1
# 4      MM6      1
# ..     ...    ...
# 526  MM834      1
# 527  MM843      2
# 528  MM835      1
# 529  MM836      2
# 530  MM838      2
#
# [531 rows x 2 columns]

# %%
data_bony_lesions
# Out:
#         ID DxType  DaysFromDx  BonyLesions
# 0      MM1    MRI       297.0            0
# 1      MM2    MRI       176.0            1
# 2      MM4    MRI       411.0            1
# 3      MM5    MRI       373.0            0
# 4      MM7    MRI       197.0            1
# ..     ...    ...         ...          ...
# 664  MM834    MRI       161.0            1
# 665  MM843    MRI       812.0            1
# 666  MM836    MRI       754.0            1
# 667  MM837    MRI       173.0            1
# 668  MM838    MRI       190.0            1
#
# [669 rows x 4 columns]

# %%
data_fracture
# Out:
#         ID  HasFracture?
# 0      MM1             0
# 1      MM2             0
# 2      MM4             0
# 3      MM5             0
# 4      MM6             0
# ..     ...           ...
# 697  MM834             0
# 698  MM843             0
# 699  MM836             0
# 700  MM837             0
# 701  MM838             0
#
# [702 rows x 2 columns]

# %%
# combine fracture data with lesions data
data_agg = data_fracture.merge(data_bony_lesions, on = 'ID', how='outer')

# %%
# combine with cancer stage data
data_agg = data_agg.merge(data_cancer_stage, on = 'ID', how='outer')

# %%
# combine with medications
data_agg = data_agg.merge(data_medications, on = 'ID', how = 'outer')

# %%
# combine with demographics data
data_agg = data_agg.merge(data_demographics, on = 'ID', how = 'outer')

# %%
data_agg
# Out:
#         ID  HasFracture? DxType  ...  AgeAtDx  PatientSex  RacialGroup
# 0      MM1           0.0    MRI  ...      1.0         1.0          1.0
# 1      MM2           0.0    MRI  ...      1.0         1.0          2.0
# 2      MM4           0.0    MRI  ...      1.0         0.0          1.0
# 3      MM5           0.0    MRI  ...      1.0         1.0          1.0
# 4      MM6           0.0    NaN  ...      1.0         1.0          1.0
# ..     ...           ...    ...  ...      ...         ...          ...
# 827  MM700           NaN    NaN  ...      1.0         1.0          1.0
# 828  MM711           NaN    NaN  ...      0.0         1.0          1.0
# 829  MM820           NaN    NaN  ...      0.0         0.0          1.0
# 830  MM956           NaN    NaN  ...      1.0         0.0          2.0
# 831  MM935           NaN    NaN  ...      1.0         0.0          1.0
#
# [832 rows x 15 columns]

# %% [markdown]
# It turns out before we combine it with lab data, we need to process the lab data somehow. We need to flag if this chemical level is normal/abnormal on this patient based on the lab sheet.

# %%
data_labs[data_labs['ObservationName'] == 'Parathyroid hormone']
# Out:
#          ID ObservationId  ... LowerLimit UpperLimit
# 39      MM7          IPTH  ...       12.0       88.0
# 103    MM18          IPTH  ...       12.0       88.0
# 157    MM26          IPTH  ...       12.0       88.0
# 167   MM844          IPTH  ...       12.0       88.0
# 184    MM29          IPTH  ...       12.0       88.0
# ...     ...           ...  ...        ...        ...
# 4675  MM715          IPTH  ...       12.0       88.0
# 4825  MM738          IPTH  ...       12.0       88.0
# 5092  MM814          IPTH  ...       12.0       88.0
# 5138  MM855          IPTH  ...       12.0       88.0
# 5149  MM822          IPTH  ...       12.0       88.0
#
# [62 rows x 10 columns]

# %% [markdown]
# can take out the rows with parathyroid hormone because less than 10% (62 / 700) of people took this lab test. Too many nulls

# %%
data_labs = data_labs[data_labs['ObservationName'] != 'Parathyroid hormone']

# %%
important_chemicals = ['Calcium', 'Phosphate', 'Parathyroid hormone', \
                       'Alkaline\xa0Phosphatase', 'Vitamin\xa0D3', \
                       'Estradiol', 'Testosterone', 'Thyroid\xa0Stimulating\xa0Hormone',\
                       'Creatinine', 'C-Reactive Protein', 'Sedimentation\xa0Rate']

# %% [markdown]
# Calcium: N: normal (0), H, L -> abnormal (1) \\
# phosphate: N: normal (0), H, L -> abnormal \\
# Parathyroid hormone: not in lab sheet \\
# Alkaline Phosphatase: L, N -> 0 normal, H -> 1 abnormal \\
# Vitamin D3: H, N -> 0 normal, L -> 1 abnormal \\
# Estradiol: H, N -> 0, L -> abnormal \\
# testoterone: H, N -> 0, L -> 1 \\
# thyroid stimulating hormone: N -> 0, H, L -> 1 \\
# creatinine: L, N -> 0, H -> 1 \\
# c-reactive protein: L, N -> 0, H -> 1 \\
# sedimentation rate: L, N -> 0, H -> 1 \\

# %%
lab_interpretation = {}
lab_interpretation['Calcium'] = {'N':0, 'H': 1, 'L': 1}
lab_interpretation['Phosphate'] = {'N':0, 'H': 1, 'L': 1}
lab_interpretation['Alkaline\xa0Phosphatase'] = {'N':0, 'H': 1, 'L': 0}
lab_interpretation['Vitamin\xa0D3'] = {'N':0, 'H': 1, 'L': 0}
lab_interpretation['Estradiol'] = {'N':0, 'H': 0, 'L': 1}
lab_interpretation['Testosterone'] = {'N':0, 'H': 0, 'L': 1}
lab_interpretation['Thyroid\xa0Stimulating\xa0Hormone'] = {'N':0, 'H': 1, 'L': 1}
lab_interpretation['Creatinine'] = {'N':0, 'H': 1, 'L': 0}
lab_interpretation['C-Reactive Protein'] = {'N':0, 'H': 1, 'L': 0}
lab_interpretation['Sedimentation\xa0Rate'] = {'N':0, 'H': 1, 'L': 0}

# %%
# transform lab results flags to match lab interpretation.
data_labs['Abnormal?'] = data_labs.apply(lambda row: lab_interpretation[row['ObservationName']][row['AbnormalFlags']], axis = 1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_labs
# Out:
#          ID ObservationId  ... UpperLimit Abnormal?
# 0       MM1            CA  ...       10.2         0
# 1       MM1             P  ...        4.5         1
# 2       MM1           ALK  ...      161.0         0
# 3       MM1         VITD3  ...      100.0         0
# 4       MM1          TEST  ...        5.9         1
# ...     ...           ...  ...        ...       ...
# 5254  MM838         VITD3  ...      100.0         0
# 5255  MM838          TEST  ...        5.9         0
# 5256  MM838           TSH  ...        5.0         1
# 5257  MM838           CRE  ...        1.2         0
# 5258  MM838         HSCRP  ...       10.0         0
#
# [5197 rows x 11 columns]

# %% [markdown]
# Now we need to convert all these rows into columns indicating whether each patient has abnormal level of each chemical.

# %%
list_of_lab_results = []
for ID in data_labs['ID'].unique():
  patient_labs = data_labs[data_labs['ID'] == ID]
  thisRow = [ID]
  for chemical in important_chemicals:
    if chemical in patient_labs['ObservationName'].unique():
      patient_labs_this_chemical = patient_labs[patient_labs['ObservationName'] == chemical]
      if patient_labs_this_chemical.shape[0] == 1:
        thisRow.append(patient_labs_this_chemical['Abnormal?'].values[0])
      else:
        if 1 in patient_labs_this_chemical['Abnormal?']:
          thisRow.append(1)
        else:
          thisRow.append(0)
    else:
      thisRow.append(None)
  list_of_lab_results.append(thisRow)

# %%
data_labs_new = pd.DataFrame(data = list_of_lab_results, columns= ['ID'] + important_chemicals)

# %%
data_labs_new.drop(['Parathyroid hormone'], axis = 1, inplace = True)

# %%
data_labs_new
# Out:
#         ID  Calcium  ...  C-Reactive Protein  Sedimentation Rate
# 0      MM1      0.0  ...                 1.0                 NaN
# 1      MM2      0.0  ...                 0.0                 NaN
# 2      MM4      0.0  ...                 0.0                 NaN
# 3      MM5      1.0  ...                 0.0                 NaN
# 4      MM6      1.0  ...                 0.0                 NaN
# ..     ...      ...  ...                 ...                 ...
# 695  MM834      0.0  ...                 1.0                 NaN
# 696  MM843      0.0  ...                 0.0                 1.0
# 697  MM836      0.0  ...                 1.0                 NaN
# 698  MM837      0.0  ...                 0.0                 NaN
# 699  MM838      1.0  ...                 0.0                 NaN
#
# [700 rows x 11 columns]

# %%
data_labs_new.isnull().sum()
# Out:
# ID                               0
# Calcium                          1
# Phosphate                        4
# Alkaline Phosphatase             1
# Vitamin D3                     135
# Estradiol                      550
# Testosterone                   387
# Thyroid Stimulating Hormone    221
# Creatinine                       1
# C-Reactive Protein              21
# Sedimentation Rate             599
# dtype: int64

# %% [markdown]
# might need to remove nulls later, but now let's combine them with our aggregated dataframe

# %%
# combine lab data with everything else
data_agg = data_agg.merge(data_labs_new, on = 'ID', how = 'outer')

# %%
data_agg
# Out:
#         ID  HasFracture?  ... C-Reactive Protein  Sedimentation Rate
# 0      MM1           0.0  ...                1.0                 NaN
# 1      MM2           0.0  ...                0.0                 NaN
# 2      MM4           0.0  ...                0.0                 NaN
# 3      MM5           0.0  ...                0.0                 NaN
# 4      MM6           0.0  ...                0.0                 NaN
# ..     ...           ...  ...                ...                 ...
# 827  MM700           NaN  ...                NaN                 NaN
# 828  MM711           NaN  ...                NaN                 NaN
# 829  MM820           NaN  ...                NaN                 NaN
# 830  MM956           NaN  ...                NaN                 NaN
# 831  MM935           NaN  ...                NaN                 NaN
#
# [832 rows x 25 columns]

# %%
# delete the rows NaN HasFracture? values since that is what we are trying to predict
data_agg = data_agg.dropna(subset = ['HasFracture?'])

# %%
data_agg
# Out:
#         ID  HasFracture?  ... C-Reactive Protein  Sedimentation Rate
# 0      MM1           0.0  ...                1.0                 NaN
# 1      MM2           0.0  ...                0.0                 NaN
# 2      MM4           0.0  ...                0.0                 NaN
# 3      MM5           0.0  ...                0.0                 NaN
# 4      MM6           0.0  ...                0.0                 NaN
# ..     ...           ...  ...                ...                 ...
# 697  MM834           0.0  ...                1.0                 NaN
# 698  MM843           0.0  ...                0.0                 1.0
# 699  MM836           0.0  ...                1.0                 NaN
# 700  MM837           0.0  ...                0.0                 NaN
# 701  MM838           0.0  ...                0.0                 NaN
#
# [702 rows x 25 columns]

# %%
# drop some columns we are not going to use in prediction
data_agg.drop(['DxType', 'DaysFromDx'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data_agg.head()
# Out:
#     ID  HasFracture?  ...  C-Reactive Protein  Sedimentation Rate
# 0  MM1           0.0  ...                 1.0                 NaN
# 1  MM2           0.0  ...                 0.0                 NaN
# 2  MM4           0.0  ...                 0.0                 NaN
# 3  MM5           0.0  ...                 0.0                 NaN
# 4  MM6           0.0  ...                 0.0                 NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# Let's save this file to csv.

# %%
data_agg.to_csv('data_agg.csv', index = False)
